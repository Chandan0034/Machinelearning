# %%
import pandas as pd
import numpy as np

# %%
task_df=pd.read_csv('task_1a_dataset.csv')
task_df
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0     Bachelors         2012  Bangalore            3   37    Male          No
# 1       Masters         2017  New Delhi            2   28    Male          No
# 2     Bachelors         2017  New Delhi            2   36    Male          No
# 3     Bachelors         2015  Bangalore            3   27    Male         Yes
# 4     Bachelors         2017  Bangalore            3   29    Male          No
# ...         ...          ...        ...          ...  ...     ...         ...
# 4628  Bachelors         2013  Bangalore            3   26  Female          No
# 4629    Masters         2013       Pune            2   37    Male          No
# 4630    Masters         2018  New Delhi            3   27    Male          No
# 4631  Bachelors         2012  Bangalore            3   30    Male         Yes
# 4632  Bachelors         2015  Bangalore            3   33    Male         Yes
#
# ...

# %%
task_df['Age'].min()
# Out:
# 22

# %%
task_df[task_df['LeaveOrNot']==1].groupby('Age')['Age'].count()
# Out:
# Age
# 22     18
# 23     16
# 24    152
# 25    176
# 26    223
# 27    224
# 28    185
# 29     75
# 30     76
# 31     37
# 32     53
# 33     40
# 34     41
# 35     45
# 36     45
# 37     43
# 38     40
# 39     39
# 40     41
# 41     23
# Name: Age, dtype: int64

# %%
task_df[task_df['LeaveOrNot']==1].groupby(['Education','City'])['City'].count().plot(kind='pie',autopct="%.1f")
# Out:
# <Axes: ylabel='City'>

# %%
task_df.groupby('')

# %%
task_df[(task_df['ExperienceInCurrentDomain']==2) &(task_df['LeaveOrNot']==1)]
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 8     Bachelors         2013       Pune            2   31  Female          No
# 18    Bachelors         2017       Pune            2   29  Female          No
# 39      Masters         2017       Pune            2   36    Male          No
# 49      Masters         2017  Bangalore            3   40  Female          No
# 79    Bachelors         2015  Bangalore            3   24  Female          No
# ...         ...          ...        ...          ...  ...     ...         ...
# 4598    Masters         2017  New Delhi            3   38  Female          No
# 4612  Bachelors         2018  Bangalore            3   31  Female          No
# 4614  Bachelors         2016  New Delhi            1   38  Female          No
# 4617  Bachelors         2018  Bangalore            3   32    Male         Yes
# 4629    Masters         2013       Pune            2   37    Male          No
#
# ...

# %%
task_df[task_df['LeaveOrNot']==1]
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 8     Bachelors         2013       Pune            2   31  Female          No
# 12    Bachelors         2018  Bangalore            3   26    Male          No
# 14    Bachelors         2017       Pune            2   37  Female          No
# 17    Bachelors         2018  New Delhi            2   34  Female          No
# 18    Bachelors         2017       Pune            2   29  Female          No
# ...         ...          ...        ...          ...  ...     ...         ...
# 4619  Bachelors         2017  Bangalore            3   28    Male          No
# 4621  Bachelors         2016  Bangalore            1   33  Female          No
# 4624  Bachelors         2015       Pune            3   32  Female         Yes
# 4629    Masters         2013       Pune            2   37    Male          No
# 4630    Masters         2018  New Delhi            3   27    Male          No
#
# ...

# %%
task_df[task_df['LeaveOrNot']==1].groupby('PaymentTier')['PaymentTier'].count().plot(kind='pie',autopct='%.1f')
# Out:
# <Axes: ylabel='PaymentTier'>
