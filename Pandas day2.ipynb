# %%
import numpy as np
import pandas as pd

# %%
movies=pd.read_csv('movies.csv')
movies.head()
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
# 4                       Evening Shadows  tt6028796
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
# 3      https://en.wikipedia.org/wiki/Why_Cheat_India
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
#
# ...

# %%
ipl=pd.read_csv('ipl-matches.csv')
ipl
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
movies.shape
# Out:
# (1629, 18)

# %%
ipl.shape
# Out:
# (950, 20)

# %%
 ipl.index
# Out:
# RangeIndex(start=0, stop=950, step=1)

# %%
ipl.columns
# Out:
# Index(['ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'method', 'Player_of_Match', 'Team1Players',
#        'Team2Players', 'Umpire1', 'Umpire2'],
#       dtype='object')

# %%
movies.describe()
# Out:
#        is_adult  year_of_release  imdb_rating     imdb_votes
# count    1629.0      1629.000000  1629.000000    1629.000000
# mean        0.0      2010.263966     5.557459    5384.263352
# std         0.0         5.381542     1.567609   14552.103231
# min         0.0      2001.000000     0.000000       0.000000
# 25%         0.0      2005.000000     4.400000     233.000000
# 50%         0.0      2011.000000     5.600000    1000.000000
# 75%         0.0      2015.000000     6.800000    4287.000000
# max         0.0      2019.000000     9.400000  310481.000000

# %%
ipl.iloc[:5,:]
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
movies.iloc[:3,:3]
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
#
#                                          poster_path
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...

# %%
ipl.loc[:2,'ID':'TossWinner']
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
#
#                               Venue            TossWinner
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals
# 2             Eden Gardens, Kolkata  Lucknow Super Giants

# %%
new_df=ipl[ipl['MatchNumber']=='Final']
new_df
# Out:
#           ID          City        Date   Season MatchNumber  \
# 0    1312200     Ahmedabad  2022-05-29     2022       Final
# 74   1254117         Dubai  2021-10-15     2021       Final
# 134  1237181           NaN  2020-11-10  2020/21       Final
# 194  1181768     Hyderabad  2019-05-12     2019       Final
# 254  1136620        Mumbai  2018-05-27     2018       Final
# 314  1082650     Hyderabad  2017-05-21     2017       Final
# 373   981019     Bangalore  2016-05-29     2016       Final
# 433   829823       Kolkata  2015-05-24     2015       Final
# 492   734049     Bangalore  2014-06-01     2014       Final
# 552   598073       Kolkata  2013-05-26     2013       Final
# 628   548381       Chennai  2012-05-27     2012       Final
# 702   501271       Chennai  2011-05-28     2011       Final
# 775   419165        Mumbai  2010-04-25  2009/10       Final
# 835   392239  Johannesburg  2009-05-24     2009       Final
# 892   336040        Mumbai  2008-06-01  2007/08       Final
#
# ...

# %%
new_df[['Season','WinningTeam']]
# Out:
#       Season            WinningTeam
# 0       2022         Gujarat Titans
# 74      2021    Chennai Super Kings
# 134  2020/21         Mumbai Indians
# 194     2019         Mumbai Indians
# 254     2018    Chennai Super Kings
# 314     2017         Mumbai Indians
# 373     2016    Sunrisers Hyderabad
# 433     2015         Mumbai Indians
# 492     2014  Kolkata Knight Riders
# 552     2013         Mumbai Indians
# 628     2012  Kolkata Knight Riders
# 702     2011    Chennai Super Kings
# 775  2009/10    Chennai Super Kings
# 835     2009        Deccan Chargers
# 892  2007/08       Rajasthan Royals

# %%
ipl[ipl['SuperOver']=='Y'].shape[0]
# Out:
# 0

# %%
ipl[(ipl['City']=="Kolkata") & (ipl['WinningTeam']=="Chennai Super Kings")].shape[0]
# Out:
# 5

# %%
ipl[ipl['TossWinner']==ipl['WinningTeam']].shape[0]
# Out:
# 489

# %%
movies.head()
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
# 4                       Evening Shadows  tt6028796
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
# 3      https://en.wikipedia.org/wiki/Why_Cheat_India
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
#
# ...

# %%
movies[(movies['imdb_rating']>8) & (movies['imdb_votes']>10000)].shape[0]
# Out:
# 43

# %%
#find the action movie which rating greater than 7.5
movies.sample(6)
# Out:
#                    title_x    imdb_id  \
# 531       Kick (2014 film)  tt2372222
# 1566  Yeh Kya Ho Raha Hai?  tt0338566
# 9         Thackeray (film)  tt7777196
# 536          Haider (film)  tt3390572
# 1453             Janasheen  tt0366630
# 339          Beiimaan Love  tt5227468
#
#                                             poster_path  \
# 531   https://upload.wikimedia.org/wikipedia/en/thum...
# 1566  https://upload.wikimedia.org/wikipedia/en/5/59...
# 9     https://upload.wikimedia.org/wikipedia/en/thum...
# 536   https://upload.wikimedia.org/wikipedia/en/thum...
# 1453  https://upload.wikimedia.org/wikipedia/en/thum...
# 339   https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                               wiki_link               title_y  \
# 531      https://en.wikipedia.org/wiki/Kick_(2014_Film)                  Kick
# 1566  https://en.wikipedia.org/wiki/Yeh_Kya_Ho_Raha_...  Yeh Kya Ho Raha Hai?
# ...

# %%
mask1=movies['genres'].str.split('|').apply(lambda x:'Action' in x)
mask2=movies['imdb_rating']>7.5
movies[mask1 & mask2]
# Out:
#                             title_x    imdb_id  \
# 0          Uri: The Surgical Strike  tt8291224
# 41             Family of Thakurganj  tt8897986
# 84                        Mukkabaaz  tt7180544
# 106                           Raazi  tt7098658
# 110   Parmanu: The Story of Pokhran  tt6826438
# 112         Bhavesh Joshi Superhero  tt6129302
# 169                The Ghazi Attack  tt6299040
# 219                Raag Desh (film)  tt6080746
# 258                   Irudhi Suttru  tt5310090
# 280                       Laal Rang  tt5600714
# 297                     Udta Punjab  tt4434004
# 354                   Dangal (film)  tt5074352
# 362               Bajrangi Bhaijaan  tt3863552
# 365          Baby (2015 Hindi film)  tt3848892
# 393      Detective Byomkesh Bakshy!  tt3447364
# 449               Titli (2014 film)  tt3019620
# 536                   Haider (film)  tt3390572
# 589                    Vishwaroopam  tt2199711
# 625                     Madras Cafe  tt2855648
# ...

# %%
ipl[~ipl['MatchNumber'].str.isdigit()]['Player_of_Match'].value_counts()
# Out:
# Player_of_Match
# KA Pollard           3
# F du Plessis         3
# SK Raina             3
# A Kumble             2
# MK Pandey            2
# YK Pathan            2
# M Vijay              2
# JJ Bumrah            2
# AB de Villiers       2
# SR Watson            2
# HH Pandya            1
# Harbhajan Singh      1
# A Nehra              1
# V Sehwag             1
# UT Yadav             1
# MS Bisla             1
# BJ Hodge             1
# MEK Hussey           1
# MS Dhoni             1
# CH Gayle             1
# MM Patel             1
# DE Bollinger         1
# AC Gilchrist         1
# RG Sharma            1
# DA Warner            1
# MC Henriques         1
# JC Buttler           1
# RM Patidar           1
# DA Miller            1
# VR Iyer              1
# SP Narine            1
# RD Gaikwad           1
# TA Boult             1
# MP Stoinis           1
# KS Williamson        1
# RR Pant              1
# SA Yadav             1
# Rashid Khan          1
# AD Russell           1
# ...

# %%
ipl['TossDecision'].value_counts().plot(kind='pie',autopct='%.1f')
# Out:
# <Axes: ylabel='count'>

# %%
ipl.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
(ipl['Team1'].value_counts()+ipl['Team2'].value_counts()).sort_values(ascending=False)
# Out:
# Mumbai Indians                 231
# Royal Challengers Bangalore    226
# Kolkata Knight Riders          223
# Chennai Super Kings            208
# Rajasthan Royals               192
# Kings XI Punjab                190
# Delhi Daredevils               161
# Sunrisers Hyderabad            152
# Deccan Chargers                 75
# Delhi Capitals                  63
# Pune Warriors                   46
# Gujarat Lions                   30
# Punjab Kings                    28
# Gujarat Titans                  16
# Rising Pune Supergiant          16
# Lucknow Super Giants            15
# Kochi Tuskers Kerala            14
# Rising Pune Supergiants         14
# Name: count, dtype: int64

# %%
# Out:
# Team2
# Mumbai Indians                 119
# Kolkata Knight Riders          118
# Rajasthan Royals               103
# Royal Challengers Bangalore    100
# Kings XI Punjab                 98
# Chennai Super Kings             97
# Sunrisers Hyderabad             83
# Delhi Daredevils                76
# Deccan Chargers                 36
# Delhi Capitals                  34
# Pune Warriors                   23
# Gujarat Lions                   14
# Punjab Kings                    10
# Gujarat Titans                   9
# Rising Pune Supergiant           9
# Rising Pune Supergiants          7
# Lucknow Super Giants             7
# Kochi Tuskers Kerala             7
# Name: count, dtype: int64

# %%
movies.head()
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
# 4                       Evening Shadows  tt6028796
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
# 3      https://en.wikipedia.org/wiki/Why_Cheat_India
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
#
# ...

# %%
movies.sort_values('title_x',ascending=False)
# Out:
#                        title_x    imdb_id  \
# 1623                  Zubeidaa  tt0255713
# 939      Zor Lagaa Ke...Haiya!  tt1479857
# 756                   Zokkomon  tt1605790
# 670          Zindagi Tere Naam  tt2164702
# 778   Zindagi Na Milegi Dobara  tt1562872
# ...                        ...        ...
# 1039          1971 (2007 film)  tt0983990
# 723     1920: The Evil Returns  tt2222550
# 287               1920: London  tt5638500
# 1021               1920 (film)  tt1301698
# 1498        16 December (film)  tt0313844
#
#                                             poster_path  \
# 1623  https://upload.wikimedia.org/wikipedia/en/thum...
# 939   https://upload.wikimedia.org/wikipedia/en/thum...
# 756   https://upload.wikimedia.org/wikipedia/en/thum...
# 670   https://upload.wikimedia.org/wikipedia/en/thum...
# 778   https://upload.wikimedia.org/wikipedia/en/thum...
# ...                                                 ...
# 1039  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
movies.sort_values(['year_of_release','title_x'])
# Out:
#                                title_x     imdb_id  \
# 1575                       Aalavandhan   tt0294264
# 1576  Aamdani Atthanni Kharcha Rupaiya   tt0305173
# 1577                Aashiq (2001 film)   tt0273406
# 1579               Ajnabee (2001 film)   tt0278291
# 1578                   Aks (2001 film)   tt0289845
# ...                                ...         ...
# 64                         Ujda Chaman  tt11046300
# 0             Uri: The Surgical Strike   tt8291224
# 3                      Why Cheat India   tt8108208
# 60                  Yaaram (2019 film)  tt11007050
# 73                  Yeh Saali Aashiqui  tt10443846
#
#                                             poster_path  \
# 1575  https://upload.wikimedia.org/wikipedia/en/thum...
# 1576  https://upload.wikimedia.org/wikipedia/en/thum...
# 1577  https://upload.wikimedia.org/wikipedia/en/c/c6...
# 1579  https://upload.wikimedia.org/wikipedia/en/thum...
# 1578  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
ipl_bat=pd.read_csv('batsman_runs_ipl.csv')
ipl_bat
# Out:
#              batter  batsman_run
# 0    A Ashish Reddy          280
# 1          A Badoni          161
# 2        A Chandila            4
# 3          A Chopra           53
# 4       A Choudhary           25
# ..              ...          ...
# 600      Yash Dayal            0
# 601   Yashpal Singh           47
# 602     Younis Khan            3
# 603    Yuvraj Singh         2754
# 604          Z Khan          117
#
# [605 rows x 2 columns]

# %%
ipl_bat["batting_rank"]=ipl_bat['batsman_run'].rank(ascending=False)

# %%
ipl_bat.sort_values('batting_rank')
# Out:
#            batter  batsman_run  batting_rank
# 569       V Kohli         6634           1.0
# 462      S Dhawan         6244           2.0
# 130     DA Warner         5883           3.0
# 430     RG Sharma         5881           4.0
# 493      SK Raina         5536           5.0
# ..            ...          ...           ...
# 512   SS Cottrell            0         594.0
# 466     S Kaushik            0         594.0
# 203     IC Pandey            0         594.0
# 467       S Ladda            0         594.0
# 468  S Lamichhane            0         594.0
#
# [605 rows x 3 columns]

# %%
movies.sort_index(ascending=False)
# Out:
#                                    title_x     imdb_id  \
# 1628                              Humsafar   tt2403201
# 1627                                 Daaka  tt10833860
# 1626                       Sabse Bada Sukh   tt0069204
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1624                 Tera Mera Saath Rahen   tt0301250
# ...                                    ...         ...
# 4                          Evening Shadows   tt6028796
# 3                          Why Cheat India   tt8108208
# 2     The Accidental Prime Minister (film)   tt6986710
# 1                            Battalion 609   tt9472208
# 0                 Uri: The Surgical Strike   tt8291224
#
#                                             poster_path  \
# 1628  https://upload.wikimedia.org/wikipedia/en/thum...
# 1627  https://upload.wikimedia.org/wikipedia/en/thum...
# 1626                                                NaN
# 1625  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %% [markdown]
# setIndex(datafram)->inplace

# %%
ipl_bat.set_index('batter',inplace=True)

# %%
ipl_bat.reset_index()
ipl_bat
# Out:
#              batter  batsman_run  batting_rank
# 0    A Ashish Reddy          280         166.5
# 1          A Badoni          161         226.0
# 2        A Chandila            4         535.0
# 3          A Chopra           53         329.0
# 4       A Choudhary           25         402.5
# ..              ...          ...           ...
# 600      Yash Dayal            0         594.0
# 601   Yashpal Singh           47         343.0
# 602     Younis Khan            3         547.5
# 603    Yuvraj Singh         2754          27.0
# 604          Z Khan          117         256.0
#
# [605 rows x 3 columns]

# %%
ipl_bat.reset_index().set_index('batting_rank')
# Out:
#               index          batter  batsman_run
# batting_rank
# 166.5             0  A Ashish Reddy          280
# 226.0             1        A Badoni          161
# 535.0             2      A Chandila            4
# 329.0             3        A Chopra           53
# 402.5             4     A Choudhary           25
# ...             ...             ...          ...
# 594.0           600      Yash Dayal            0
# 343.0           601   Yashpal Singh           47
# 547.5           602     Younis Khan            3
# 27.0            603    Yuvraj Singh         2754
# 256.0           604          Z Khan          117
#
# [605 rows x 3 columns]

# %%
ipl_bat['batter'].hasnans
# Out:
# False

# %%
movies.isnull().sum()
# Out:
# title_x                0
# imdb_id                0
# poster_path          103
# wiki_link              0
# title_y                0
# original_title         0
# is_adult               0
# year_of_release        0
# runtime                0
# genres                 0
# imdb_rating            0
# imdb_votes             0
# story                 20
# summary                0
# tagline             1072
# actors                 5
# wins_nominations     922
# release_date         107
# dtype: int64

# %%
movies.dropna()
# Out:
#                       title_x     imdb_id  \
# 11                  Gully Boy   tt2395469
# 34              Yeh Hai India   tt5525846
# 37          Article 15 (film)  tt10324144
# 87                    Aiyaary   tt6774212
# 96           Raid (2018 film)   tt7363076
# ...                       ...         ...
# 1600                   Kasoor   tt0272688
# 1601         Maya (2001 film)   tt0299027
# 1607  Nayak (2001 Hindi film)   tt0291376
# 1621                  Tum Bin   tt0290326
# 1623                 Zubeidaa   tt0255713
#
#                                             poster_path  \
# 11    https://upload.wikimedia.org/wikipedia/en/thum...
# 34    https://upload.wikimedia.org/wikipedia/en/thum...
# 37    https://upload.wikimedia.org/wikipedia/en/thum...
# 87    https://upload.wikimedia.org/wikipedia/en/thum...
# 96    https://upload.wikimedia.org/wikipedia/en/thum...
# ...                                                 ...
# 1600  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
movies.dropna(how='all')
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
movies.dropna(how='any')
# Out:
#                       title_x     imdb_id  \
# 11                  Gully Boy   tt2395469
# 34              Yeh Hai India   tt5525846
# 37          Article 15 (film)  tt10324144
# 87                    Aiyaary   tt6774212
# 96           Raid (2018 film)   tt7363076
# ...                       ...         ...
# 1600                   Kasoor   tt0272688
# 1601         Maya (2001 film)   tt0299027
# 1607  Nayak (2001 Hindi film)   tt0291376
# 1621                  Tum Bin   tt0290326
# 1623                 Zubeidaa   tt0255713
#
#                                             poster_path  \
# 11    https://upload.wikimedia.org/wikipedia/en/thum...
# 34    https://upload.wikimedia.org/wikipedia/en/thum...
# 37    https://upload.wikimedia.org/wikipedia/en/thum...
# 87    https://upload.wikimedia.org/wikipedia/en/thum...
# 96    https://upload.wikimedia.org/wikipedia/en/thum...
# ...                                                 ...
# 1600  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
movies
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
movies.dropna(subset=['tagline'])
# Out:
#                         title_x    imdb_id  \
# 7                    Bombairiya  tt4971258
# 11                    Gully Boy  tt2395469
# 13                Total Dhamaal  tt7639372
# 20    Mere Pyare Prime Minister  tt8207768
# 34                Yeh Hai India  tt5525846
# ...                         ...        ...
# 1601           Maya (2001 film)  tt0299027
# 1607    Nayak (2001 Hindi film)  tt0291376
# 1620   Yeh Raaste Hain Pyaar Ke  tt0292740
# 1621                    Tum Bin  tt0290326
# 1623                   Zubeidaa  tt0255713
#
#                                             poster_path  \
# 7     https://upload.wikimedia.org/wikipedia/en/thum...
# 11    https://upload.wikimedia.org/wikipedia/en/thum...
# 13    https://upload.wikimedia.org/wikipedia/en/thum...
# 20    https://upload.wikimedia.org/wikipedia/en/thum...
# 34    https://upload.wikimedia.org/wikipedia/en/thum...
# ...                                                 ...
# ...

# %%
movies
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
movies['tagline'].isnull().sum()
# Out:
# 1072

# %% [raw]
# fillna(method='ffill','bfill')

# %%
df=pd.read_csv('diabetes.csv')
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %% [raw]
# drop_duplicates(Series+dataframe)

# %%
df.drop_duplicates()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
ipl
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
ipl['all_player']=ipl['Team1Players']+ipl['Team2Players']
ipl.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  ...  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat  ...
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field  ...
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field  ...
# ...

# %%
ipl['all_player'].str.apply(lambda x : x=="V Kohli")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[124], line 1
# ----> 1 ipl['all_player'].str.apply(lambda x : x=="V Kohli")
#
# AttributeError: 'StringMethods' object has no attribute 'apply'

# %%
ipl_match=pd.read_csv('IPL Matches 2008-2020.csv')
ipl_match['venue'].value_counts()
# Out:
# venue
# Eden Gardens                                            77
# Feroz Shah Kotla                                        74
# Wankhede Stadium                                        73
# M Chinnaswamy Stadium                                   65
# Rajiv Gandhi International Stadium, Uppal               64
# MA Chidambaram Stadium, Chepauk                         57
# Sawai Mansingh Stadium                                  47
# Punjab Cricket Association Stadium, Mohali              35
# Dubai International Cricket Stadium                     33
# Sheikh Zayed Stadium                                    29
# Punjab Cricket Association IS Bindra Stadium, Mohali    21
# Maharashtra Cricket Association Stadium                 21
# Sharjah Cricket Stadium                                 18
# Dr DY Patil Sports Academy                              17
# Subrata Roy Sahara Stadium                              17
# M.Chinnaswamy Stadium                                   15
# ...

# %%
ipl
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
ipl[(ipl['Venue']=="Eden Gardens") ]
# Out:
#           ID     City        Date   Season MatchNumber  \
# 207  1178422  Kolkata  2019-04-28     2019          47
# 211  1178418  Kolkata  2019-04-25     2019          43
# 219  1178410  Kolkata  2019-04-19     2019          35
# 224  1178404  Kolkata  2019-04-14     2019          29
# 228  1178401  Kolkata  2019-04-12     2019          26
# ..       ...      ...         ...      ...         ...
# 908   336025  Kolkata  2008-05-18  2007/08          41
# 915   336017  Kolkata  2008-05-13  2007/08          35
# 922   336010  Kolkata  2008-05-08  2007/08          29
# 934   335997  Kolkata  2008-04-29  2007/08          16
# 945   335986  Kolkata  2008-04-20  2007/08           4
#
#                            Team1                        Team2         Venue  \
# 207        Kolkata Knight Riders               Mumbai Indians  Eden Gardens
# 211        Kolkata Knight Riders             Rajasthan Royals  Eden Gardens
# ...

# %%
ipl[(ipl['Venue']=="Eden Gardens") & (ipl['TossDecision']=="bat")]
# Out:
#          ID     City        Date   Season  MatchNumber                  Team1  \
# 389  980989  Kolkata  2016-05-14     2016           45  Kolkata Knight Riders
# 449  829791  Kolkata  2015-05-09     2015           44  Kolkata Knight Riders
# 452  829761  Kolkata  2015-05-07     2015           42  Kolkata Knight Riders
# 552  598073  Kolkata  2013-05-26     2013        Final    Chennai Super Kings
# 553  598072  Kolkata  2013-05-24     2013  Qualifier 2         Mumbai Indians
# 581  598043  Kolkata  2013-05-03     2013           47  Kolkata Knight Riders
# 593  598031  Kolkata  2013-04-26     2013           35  Kolkata Knight Riders
# 595  598029  Kolkata  2013-04-24     2013           33  Kolkata Knight Riders
# 602  598022  Kolkata  2013-04-20     2013           26  Kolkata Knight Riders
# 611  598013  Kolkata  2013-04-14     2013           17  Kolkata Knight Riders
# 646  548363  Kolkata  2012-05-12     2012           58  Kolkata Knight Riders
# ...

# %%
ipl[(ipl['TossWinner']==ipl['WinningTeam'])& (ipl['TossDecision']=="field") & (ipl['Venue'].str.contains("Eden Gardens"))]
# Out:
#           ID     City        Date   Season  MatchNumber  \
# 3    1312197  Kolkata  2022-05-24     2022  Qualifier 1
# 211  1178418  Kolkata  2019-04-25     2019           43
# 224  1178404  Kolkata  2019-04-14     2019           29
# 228  1178401  Kolkata  2019-04-12     2019           26
# 252  1175357  Kolkata  2019-03-24     2019            2
# 265  1136609  Kolkata  2018-05-15     2018           49
# 281  1136593  Kolkata  2018-05-03     2018           33
# 296  1136578  Kolkata  2018-04-21     2018           18
# 304  1136570  Kolkata  2018-04-14     2018           10
# 312  1136563  Kolkata  2018-04-08     2018            3
# 333  1082631  Kolkata  2017-05-03     2017           41
# 341  1082622  Kolkata  2017-04-28     2017           32
# 350  1082613  Kolkata  2017-04-21     2017           23
# 362  1082601  Kolkata  2017-04-13     2017           11
# 385   980995  Kolkata  2016-05-16     2016           48
# 395   980975  Kolkata  2016-05-08     2016           38
# ...

# %%
ipl[(ipl['TossWinner']==ipl['WinningTeam'])& (ipl['TossDecision']=="bat") & (ipl['Venue'].str.contains("Punjab Cricket Association Stadium"))]
# Out:
#           ID    City        Date Season  MatchNumber  \
# 20   1304100  Mumbai  2022-05-08   2022           54
# 29   1304091  Mumbai  2022-05-01   2022           45
# 115  1254076  Mumbai  2021-04-25   2021           19
# 203  1178426  Mumbai  2019-05-02   2019           51
# 436   829817  Mumbai  2015-05-19   2015  Qualifier 1
# 447   829795  Mumbai  2015-05-10   2015           46
# 469   829751  Mumbai  2015-04-25   2015           23
# 576   598050  Mumbai  2013-05-07   2013           53
# 579   598046  Mumbai  2013-05-05   2013           49
# 587   598037  Mumbai  2013-04-29   2013           41
# 591   598033  Mumbai  2013-04-27   2013           37
# 613   598011  Mumbai  2013-04-13   2013           15
# 619   598006  Mumbai  2013-04-09   2013           10
# 718   501256  Mumbai  2011-05-14   2011           59
#
#                            Team1                        Team2  \
# 20   Royal Challengers Bangalore          Sunrisers Hyderabad
# ...

# %%
ipl.sample(10)
# Out:
#           ID       City        Date   Season MatchNumber  \
# 52   1304068     Mumbai  2022-04-12     2022          22
# 533   729315  Abu Dhabi  2014-04-29     2014          19
# 750   501223      Delhi  2011-04-23     2011          26
# 461   829769     Mumbai  2015-05-01     2015          32
# 93   1254092    Sharjah  2021-09-28     2021          41
# 861   392213  Centurion  2009-05-07     2009          33
# 174  1216511  Abu Dhabi  2020-10-06  2020/21          20
# 675   548333      Delhi  2012-04-21     2012          27
# 364  1082599       Pune  2017-04-11     2017           9
# 451   829787     Mumbai  2015-05-07     2015          41
#
#                            Team1                        Team2  \
# 52           Chennai Super Kings  Royal Challengers Bangalore
# 533        Kolkata Knight Riders             Rajasthan Royals
# 750             Delhi Daredevils              Kings XI Punjab
# 461               Mumbai Indians             Rajasthan Royals
# ...

# %%
ipl[(ipl['TossWinner']==ipl['WinningTeam'])& (ipl['TossDecision']=="field") & (ipl['Venue'].str.contains("MA Chidambaram Stadium"))]
# Out:
#           ID     City        Date   Season MatchNumber  \
# 117  1254074  Chennai  2021-04-23     2021          17
# 133  1254058  Chennai  2021-04-09     2021           1
# 213  1178416  Chennai  2019-04-23     2019          41
# 231  1178398  Chennai  2019-04-09     2019          23
# 253  1175356  Chennai  2019-03-23     2019           1
# 309  1136565  Chennai  2018-04-10     2018           5
# 612   598012  Chennai  2013-04-13     2013          16
# 645   548364  Chennai  2012-05-12     2012          59
# 701   548306  Chennai  2012-04-04     2012           1
# 924   336007  Chennai  2008-05-06  2007/08          26
#
#                            Team1                        Team2  \
# 117               Mumbai Indians                 Punjab Kings
# 133               Mumbai Indians  Royal Challengers Bangalore
# 213          Sunrisers Hyderabad          Chennai Super Kings
# 231        Kolkata Knight Riders          Chennai Super Kings
# ...

# %%
ipl[(ipl['TossWinner']==ipl['WinningTeam'])& (ipl['TossDecision']=="bat") & (ipl['Venue'].str.contains("Dr DY Patil Sports Academy"))]
# Out:
#           ID         City        Date   Season MatchNumber  \
# 8    1304112  Navi Mumbai  2022-05-18     2022          66
# 39   1304081  Navi Mumbai  2022-04-23     2022          35
# 775   419165       Mumbai  2010-04-25  2009/10       Final
# 777   419163       Mumbai  2010-04-22  2009/10  Semi Final
# 778   419162       Mumbai  2010-04-21  2009/10  Semi Final
#
#                            Team1                  Team2  \
# 8           Lucknow Super Giants  Kolkata Knight Riders
# 39                Gujarat Titans  Kolkata Knight Riders
# 775          Chennai Super Kings         Mumbai Indians
# 777          Chennai Super Kings        Deccan Chargers
# 778  Royal Challengers Bangalore         Mumbai Indians
#
#                                   Venue            TossWinner TossDecision  \
# 8    Dr DY Patil Sports Academy, Mumbai  Lucknow Super Giants          bat
# 39   Dr DY Patil Sports Academy, Mumbai        Gujarat Titans          bat
# ...

# %%
tcs=pd.read_csv('TCS.csv')
tcs.isnull().sum()
# Out:
# Date                     0
# Symbol                   0
# Series                   0
# Prev Close               0
# Open                     0
# High                     0
# Low                      0
# Last                     0
# Close                    0
# VWAP                     0
# Volume                   0
# Turnover                 0
# Trades                1683
# Deliverable Volume       0
# %Deliverble              0
# dtype: int64

# %%
tcs.head()
# Out:
#          Date Symbol Series  Prev Close    Open    High     Low    Last  \
# 0  2004-08-25    TCS     EQ      850.00  1198.7  1198.7  979.00  985.00
# 1  2004-08-26    TCS     EQ      987.95   992.0   997.0  975.30  976.85
# 2  2004-08-27    TCS     EQ      979.00   982.4   982.4  958.55  961.20
# 3  2004-08-30    TCS     EQ      962.65   969.9   990.0  965.00  986.40
# 4  2004-08-31    TCS     EQ      986.75   986.5   990.0  976.00  987.80
#
#     Close     VWAP    Volume      Turnover  Trades  Deliverable Volume  \
# 0  987.95  1008.32  17116372  1.725876e+15     NaN             5206360
# 1  979.00   985.65   5055400  4.982865e+14     NaN             1294899
# 2  962.65   969.94   3830750  3.715586e+14     NaN              976527
# 3  986.75   982.65   3058151  3.005106e+14     NaN              701664
# 4  988.10   982.18   2649332  2.602133e+14     NaN              695234
#
#    %Deliverble
# 0       0.3042
# 1       0.2561
# 2       0.2549
# 3       0.2294
# 4       0.2624

# %%
tcs[(tcs['Open']-tcs['Close'])==0]
# Out:
#             Date Symbol Series  Prev Close     Open     High      Low  \
# 566   2006-11-24    TCS     EQ     1144.15  1150.00  1156.90  1136.15
# 981   2008-07-25    TCS     EQ      802.55   799.20   849.50   782.00
# 1000  2008-08-22    TCS     EQ      817.85   819.00   824.75   803.50
# 1205  2009-07-02    TCS     EQ      392.95   390.00   395.30   381.20
# 1923  2012-05-17    TCS     EQ     1223.40  1222.00  1235.00  1199.05
# 2189  2013-06-10    TCS     EQ     1518.95  1525.05  1544.70  1519.10
# 3001  2016-09-26    TCS     EQ     2398.10  2401.10  2419.10  2395.00
# 3938  2020-07-13    TCS     EQ     2222.35  2220.00  2244.95  2210.00
# 3984  2020-09-15    TCS     EQ     2491.40  2491.40  2538.00  2464.60
#
#          Last    Close     VWAP   Volume      Turnover    Trades  \
# 566   1149.25  1150.00  1151.20   801326  9.224854e+13       NaN
# 981    804.00   799.20   800.09  2210634  1.768698e+14       NaN
# 1000   817.00   819.00   813.68   661321  5.381031e+13       NaN
# ...

# %% [markdown]
# #Apply function
