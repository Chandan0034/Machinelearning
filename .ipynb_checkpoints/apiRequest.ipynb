# %%
import requests
import json
import pandas as pd

# %%
url_nifty="https://www.nseindia.com/api/option-chain-indices?symbol=NIFTY"
headers = {'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.149 Safari/537.36',
            'accept-language': 'en,gu;q=0.9,hi;q=0.8',
            'accept-encoding': 'gzip, deflate, br'}

# %%
try:
        
        response = requests.get(url_nifty, headers=headers, timeout=5)
        data=json.loads(response.text)
        lists=data['records']['data']
        strikePrice=[]
        l=[]
        expiryDate=[]
        PutEuropean=[]
        d={}
        s=0
        l.append(lists[0])
        for d in lists:
                strikePrice.append(d['strikePrice'])
                if "PE" in d:
                        PutEuropean.append(d['PE'])
               
except:
        print("Network Issue")
# Out:
# Network Issue

# %%
l=0
for i in range(0,709):
        print(l)
        l+=1
        if i < len(lists) and "PE" in lists[i]:
               print(lists[i]["PE"])
               
        else:
                print("Key 'PE' not found in dictionary or index out of range.")
# Out:
# 0
# {'strikePrice': 11000, 'expiryDate': '28-Dec-2023', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY28-12-2023PE11000.00', 'openInterest': 136.5, 'changeinOpenInterest': 1, 'pchangeinOpenInterest': 0.7380073800738007, 'totalTradedVolume': 1, 'impliedVolatility': 76.27, 'lastPrice': 1.7, 'change': 0, 'pChange': 0, 'totalBuyQuantity': 7300, 'totalSellQuantity': 500, 'bidQty': 2050, 'bidprice': 1, 'askQty': 200, 'askPrice': 2.45, 'underlyingValue': 20133.15}
# 1
# {'strikePrice': 11000, 'expiryDate': '31-Dec-2026', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY31-12-2026PE11000.00', 'openInterest': 0, 'changeinOpenInterest': 0, 'pchangeinOpenInterest': 0, 'totalTradedVolume': 0, 'impliedVolatility': 0, 'lastPrice': 25.5, 'change': 0, 'pChange': 0, 'totalBuyQuantity': 250, 'totalSellQuantity': 0, 'bidQty': 250, 'bidprice': 1.05, 'askQty': 0, 'askPrice': 0, 'underlyingValue': 20133.15}
# 2
# {'strikePrice': 12000, 'expiryDate': '28-Dec-2023', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY28-12-2023PE12000.00', 'openInterest': 446, 'changeinOpenInterest': 102, 'pchangeinOpenInterest': 29.651162790697676, 'totalTradedVolume': 150, 'impliedVolatility': 66.08, 'lastPrice': 1.7, 'change': -1.0000000000000002, 'pChange': -37.03703703703704, 'totalBuyQuantity': 4800, 'totalSellQuantity': 2000, 'bidQty': 50, 'bidprice': 1.75, 'askQty': 250, 'askPrice': 2.7, 'underlyingValue': 20133.15}
# 3
# {'strikePrice': 12000, 'expiryDate': '25-Jun-2026', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY25-06-2026PE12000.00', 'openInterest': 10, 'changeinOpenInterest': 0, 'pchangeinOpenInterest': 0, 'totalTradedVolume': 0, 'impliedVolatility': 0, 'lastPrice': 10.05, 'change': 0, 'pChange': 0, 'totalBuyQuantity': 550, 'totalSellQuantity': 0, 'bidQty': 550, 'bidprice': 12, 'askQty': 0, 'askPrice': 0, 'underlyingValue': 20133.15}
# 4
# {'strikePrice': 12000, 'expiryDate': '31-Dec-2026', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY31-12-2026PE12000.00', 'openInterest': 12, 'changeinOpenInterest': 0, 'pchangeinOpenInterest': 0, 'totalTradedVolume': 0, 'impliedVolatility': 0, 'lastPrice': 250.1, 'change': 0, 'pChange': 0, 'totalBuyQuantity': 250, 'totalSellQuantity': 0, 'bidQty': 250, 'bidprice': 18.2, 'askQty': 0, 'askPrice': 0, 'underlyingValue': 20133.15}
# 5
# {'strikePrice': 12700, 'expiryDate': '28-Dec-2023', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY28-12-2023PE12700.00', 'openInterest': 211, 'changeinOpenInterest': -6724, 'pchangeinOpenInterest': -96.95746214852198, 'totalTradedVolume': 7510, 'impliedVolatility': 60.48, 'lastPrice': 2.05, 'change': -3.6500000000000004, 'pChange': -64.03508771929825, 'totalBuyQuantity': 3700, 'totalSellQuantity': 100, 'bidQty': 1800, 'bidprice': 0.7, 'askQty': 50, 'askPrice': 3, 'underlyingValue': 20133.15}
# 6
# {'strikePrice': 13000, 'expiryDate': '28-Dec-2023', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY28-12-2023PE13000.00', 'openInterest': 4050, 'changeinOpenInterest': 53, 'pchangeinOpenInterest': 1.3259944958719039, 'totalTradedVolume': 170, 'impliedVolatility': 58.59, 'lastPrice': 2.4, 'change': -0.30000000000000027, 'pChange': -11.11111111111112, 'totalBuyQuantity': 9650, 'totalSellQuantity': 9300, 'bidQty': 100, 'bidprice': 2, 'askQty': 100, 'askPrice': 2.4, 'underlyingValue': 20133.15}
# 7
# {'strikePrice': 13000, 'expiryDate': '24-Dec-2025', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY24-12-2025PE13000.00', 'openInterest': 3, 'changeinOpenInterest': 0, 'pchangeinOpenInterest': 0, 'totalTradedVolume': 0, 'impliedVolatility': 0, 'lastPrice': 400, 'change': 0, 'pChange': 0, 'totalBuyQuantity': 500, 'totalSellQuantity': 0, 'bidQty': 250, 'bidprice': 2.3, 'askQty': 0, 'askPrice': 0, 'underlyingValue': 20133.15}
# 8
# {'strikePrice': 13000, 'expiryDate': '25-Jun-2026', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY25-06-2026PE13000.00', 'openInterest': 4, 'changeinOpenInterest': 0, 'pchangeinOpenInterest': 0, 'totalTradedVolume': 0, 'impliedVolatility': 0, 'lastPrice': 45.25, 'change': 0, 'pChange': 0, 'totalBuyQuantity': 250, 'totalSellQuantity': 0, 'bidQty': 250, 'bidprice': 1.05, 'askQty': 0, 'askPrice': 0, 'underlyingValue': 20133.15}
# 9
# {'strikePrice': 13000, 'expiryDate': '31-Dec-2026', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY31-12-2026PE13000.00', 'openInterest': 4, 'changeinOpenInterest': 0, 'pchangeinOpenInterest': 0, 'totalTradedVolume': 0, 'impliedVolatility': 0, 'lastPrice': 450, 'change': 0, 'pChange': 0, 'totalBuyQuantity': 250, 'totalSellQuantity': 0, 'bidQty': 250, 'bidprice': 21.4, 'askQty': 0, 'askPrice': 0, 'underlyingValue': 20133.15}
# 10
# {'strikePrice': 13500, 'expiryDate': '28-Dec-2023', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY28-12-2023PE13500.00', 'openInterest': 254, 'changeinOpenInterest': -3, 'pchangeinOpenInterest': -1.1673151750972763, 'totalTradedVolume': 251, 'impliedVolatility': 52.05, 'lastPrice': 1.65, 'change': -1.8000000000000003, 'pChange': -52.17391304347827, 'totalBuyQuantity': 4600, 'totalSellQuantity': 3800, 'bidQty': 1000, 'bidprice': 1.65, 'askQty': 100, 'askPrice': 2, 'underlyingValue': 20133.15}
# 11
# {'strikePrice': 14000, 'expiryDate': '28-Dec-2023', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY28-12-2023PE14000.00', 'openInterest': 1950, 'changeinOpenInterest': -34, 'pchangeinOpenInterest': -1.7137096774193548, 'totalTradedVolume': 390, 'impliedVolatility': 49.11, 'lastPrice': 2.2, 'change': -0.8499999999999996, 'pChange': -27.868852459016384, 'totalBuyQuantity': 10750, 'totalSellQuantity': 3700, 'bidQty': 1000, 'bidprice': 2, 'askQty': 150, 'askPrice': 2.5, 'underlyingValue': 20133.15}
# 12
# {'strikePrice': 14000, 'expiryDate': '28-Mar-2024', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY28-03-2024PE14000.00', 'openInterest': 0, 'changeinOpenInterest': 0, 'pchangeinOpenInterest': 0, 'totalTradedVolume': 0, 'impliedVolatility': 0, 'lastPrice': 0, 'change': 0, 'pChange': 0, 'totalBuyQuantity': 4400, 'totalSellQuantity': 0, 'bidQty': 4400, 'bidprice': 3.05, 'askQty': 0, 'askPrice': 0, 'underlyingValue': 20133.15}
# 13
# {'strikePrice': 14000, 'expiryDate': '27-Jun-2024', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY27-06-2024PE14000.00', 'openInterest': 145.5, 'changeinOpenInterest': 0, 'pchangeinOpenInterest': 0, 'totalTradedVolume': 0, 'impliedVolatility': 0, 'lastPrice': 6.35, 'change': 0, 'pChange': 0, 'totalBuyQuantity': 203150, 'totalSellQuantity': 0, 'bidQty': 1350, 'bidprice': 3.05, 'askQty': 0, 'askPrice': 0, 'underlyingValue': 20133.15}
# 14
# {'strikePrice': 14000, 'expiryDate': '26-Sep-2024', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY26-09-2024PE14000.00', 'openInterest': 0, 'changeinOpenInterest': 0, 'pchangeinOpenInterest': 0, 'totalTradedVolume': 0, 'impliedVolatility': 0, 'lastPrice': 0, 'change': 0, 'pChange': 0, 'totalBuyQuantity': 1250, 'totalSellQuantity': 0, 'bidQty': 1250, 'bidprice': 4.7, 'askQty': 0, 'askPrice': 0, 'underlyingValue': 20133.15}
# 15
# {'strikePrice': 14000, 'expiryDate': '26-Dec-2024', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY26-12-2024PE14000.00', 'openInterest': 66, 'changeinOpenInterest': 0, 'pchangeinOpenInterest': 0, 'totalTradedVolume': 0, 'impliedVolatility': 0, 'lastPrice': 20.5, 'change': 0, 'pChange': 0, 'totalBuyQuantity': 3150, 'totalSellQuantity': 0, 'bidQty': 2600, 'bidprice': 12.05, 'askQty': 0, 'askPrice': 0, 'underlyingValue': 20133.15}
# 16
# {'strikePrice': 14000, 'expiryDate': '26-Jun-2025', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY26-06-2025PE14000.00', 'openInterest': 13.5, 'changeinOpenInterest': 0, 'pchangeinOpenInterest': 0, 'totalTradedVolume': 0, 'impliedVolatility': 0, 'lastPrice': 42.35, 'change': 0, 'pChange': 0, 'totalBuyQuantity': 950, 'totalSellQuantity': 0, 'bidQty': 350, 'bidprice': 20.9, 'askQty': 0, 'askPrice': 0, 'underlyingValue': 20133.15}
# 17
# {'strikePrice': 14000, 'expiryDate': '24-Dec-2025', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY24-12-2025PE14000.00', 'openInterest': 0, 'changeinOpenInterest': 0, 'pchangeinOpenInterest': 0, 'totalTradedVolume': 0, 'impliedVolatility': 0, 'lastPrice': 0, 'change': 0, 'pChange': 0, 'totalBuyQuantity': 550, 'totalSellQuantity': 0, 'bidQty': 550, 'bidprice': 22.05, 'askQty': 0, 'askPrice': 0, 'underlyingValue': 20133.15}
# 18
# {'strikePrice': 14000, 'expiryDate': '25-Jun-2026', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY25-06-2026PE14000.00', 'openInterest': 2, 'changeinOpenInterest': 0, 'pchangeinOpenInterest': 0, 'totalTradedVolume': 0, 'impliedVolatility': 0, 'lastPrice': 300, 'change': 0, 'pChange': 0, 'totalBuyQuantity': 550, 'totalSellQuantity': 0, 'bidQty': 550, 'bidprice': 23.3, 'askQty': 0, 'askPrice': 0, 'underlyingValue': 20133.15}
# 19
# {'strikePrice': 14000, 'expiryDate': '31-Dec-2026', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY31-12-2026PE14000.00', 'openInterest': 19, 'changeinOpenInterest': 0, 'pchangeinOpenInterest': 0, 'totalTradedVolume': 0, 'impliedVolatility': 0, 'lastPrice': 500, 'change': 0, 'pChange': 0, 'totalBuyQuantity': 1050, 'totalSellQuantity': 0, 'bidQty': 550, 'bidprice': 24.5, 'askQty': 0, 'askPrice': 0, 'underlyingValue': 20133.15}
# 20
# {'strikePrice': 14000, 'expiryDate': '24-Jun-2027', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY24-06-2027PE14000.00', 'openInterest': 0, 'changeinOpenInterest': 0, 'pchangeinOpenInterest': 0, 'totalTradedVolume': 0, 'impliedVolatility': 0, 'lastPrice': 0, 'change': 0, 'pChange': 0, 'totalBuyQuantity': 550, 'totalSellQuantity': 0, 'bidQty': 550, 'bidprice': 25.5, 'askQty': 0, 'askPrice': 0, 'underlyingValue': 20133.15}
# 21
# {'strikePrice': 14000, 'expiryDate': '30-Dec-2027', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY30-12-2027PE14000.00', 'openInterest': 0, 'changeinOpenInterest': 0, 'pchangeinOpenInterest': 0, 'totalTradedVolume': 0, 'impliedVolatility': 0, 'lastPrice': 0, 'change': 0, 'pChange': 0, 'totalBuyQuantity': 550, 'totalSellQuantity': 0, 'bidQty': 550, 'bidprice': 26.3, 'askQty': 0, 'askPrice': 0, 'underlyingValue': 20133.15}
# 22
# {'strikePrice': 14000, 'expiryDate': '29-Jun-2028', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY29-06-2028PE14000.00', 'openInterest': 0, 'changeinOpenInterest': 0, 'pchangeinOpenInterest': 0, 'totalTradedVolume': 0, 'impliedVolatility': 0, 'lastPrice': 0, 'change': 0, 'pChange': 0, 'totalBuyQuantity': 550, 'totalSellQuantity': 0, 'bidQty': 550, 'bidprice': 26.9, 'askQty': 0, 'askPrice': 0, 'underlyingValue': 20133.15}
# 23
# {'strikePrice': 14500, 'expiryDate': '28-Dec-2023', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY28-12-2023PE14500.00', 'openInterest': 1177, 'changeinOpenInterest': 18, 'pchangeinOpenInterest': 1.553062985332183, 'totalTradedVolume': 34, 'impliedVolatility': 44.73, 'lastPrice': 2.15, 'change': -0.9500000000000002, 'pChange': -30.645161290322587, 'totalBuyQuantity': 4400, 'totalSellQuantity': 50, 'bidQty': 800, 'bidprice': 2.15, 'askQty': 50, 'askPrice': 2.5, 'underlyingValue': 20133.15}
# 24
# {'strikePrice': 15000, 'expiryDate': '28-Dec-2023', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY28-12-2023PE15000.00', 'openInterest': 5738, 'changeinOpenInterest': 25, 'pchangeinOpenInterest': 0.43759845965342203, 'totalTradedVolume': 144, 'impliedVolatility': 41.64, 'lastPrice': 2.75, 'change': -0.7999999999999998, 'pChange': -22.53521126760563, 'totalBuyQuantity': 13550, 'totalSellQuantity': 8250, 'bidQty': 100, 'bidprice': 2.5, 'askQty': 300, 'askPrice': 3.25, 'underlyingValue': 20133.15}
# 25
# {'strikePrice': 15000, 'expiryDate': '28-Mar-2024', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY28-03-2024PE15000.00', 'openInterest': 72, 'changeinOpenInterest': 0, 'pchangeinOpenInterest': 0, 'totalTradedVolume': 0, 'impliedVolatility': 0, 'lastPrice': 24.5, 'change': 0, 'pChange': 0, 'totalBuyQuantity': 9500, 'totalSellQuantity': 0, 'bidQty': 9300, 'bidprice': 3.05, 'askQty': 0, 'askPrice': 0, 'underlyingValue': 20133.15}
# 26
# {'strikePrice': 15000, 'expiryDate': '27-Jun-2024', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY27-06-2024PE15000.00', 'openInterest': 249.5, 'changeinOpenInterest': 0, 'pchangeinOpenInterest': 0, 'totalTradedVolume': 0, 'impliedVolatility': 0, 'lastPrice': 30, 'change': 0, 'pChange': 0, 'totalBuyQuantity': 4300, 'totalSellQuantity': 0, 'bidQty': 4250, 'bidprice': 6.85, 'askQty': 0, 'askPrice': 0, 'underlyingValue': 20133.15}
# 27
# {'strikePrice': 15000, 'expiryDate': '26-Sep-2024', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY26-09-2024PE15000.00', 'openInterest': 0, 'changeinOpenInterest': 0, 'pchangeinOpenInterest': 0, 'totalTradedVolume': 0, 'impliedVolatility': 0, 'lastPrice': 0, 'change': 0, 'pChange': 0, 'totalBuyQuantity': 350, 'totalSellQuantity': 0, 'bidQty': 350, 'bidprice': 20.55, 'askQty': 0, 'askPrice': 0, 'underlyingValue': 20133.15}
# 28
# {'strikePrice': 15000, 'expiryDate': '26-Dec-2024', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY26-12-2024PE15000.00', 'openInterest': 550, 'changeinOpenInterest': 0, 'pchangeinOpenInterest': 0, 'totalTradedVolume': 0, 'impliedVolatility': 0, 'lastPrice': 65.55, 'change': 0, 'pChange': 0, 'totalBuyQuantity': 3850, 'totalSellQuantity': 0, 'bidQty': 2300, 'bidprice': 21.5, 'askQty': 0, 'askPrice': 0, 'underlyingValue': 20133.15}
# 29
# {'strikePrice': 15000, 'expiryDate': '26-Jun-2025', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY26-06-2025PE15000.00', 'openInterest': 36, 'changeinOpenInterest': 0, 'pchangeinOpenInterest': 0, 'totalTradedVolume': 0, 'impliedVolatility': 0, 'lastPrice': 134, 'change': 0, 'pChange': 0, 'totalBuyQuantity': 900, 'totalSellQuantity': 0, 'bidQty': 500, 'bidprice': 24.25, 'askQty': 0, 'askPrice': 0, 'underlyingValue': 20133.15}
# 30
# {'strikePrice': 15000, 'expiryDate': '24-Dec-2025', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY24-12-2025PE15000.00', 'openInterest': 22, 'changeinOpenInterest': 0, 'pchangeinOpenInterest': 0, 'totalTradedVolume': 0, 'impliedVolatility': 0, 'lastPrice': 62.15, 'change': 0, 'pChange': 0, 'totalBuyQuantity': 1050, 'totalSellQuantity': 0, 'bidQty': 550, 'bidprice': 27.35, 'askQty': 0, 'askPrice': 0, 'underlyingValue': 20133.15}
# 31
# {'strikePrice': 15000, 'expiryDate': '25-Jun-2026', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY25-06-2026PE15000.00', 'openInterest': 17, 'changeinOpenInterest': 0, 'pchangeinOpenInterest': 0, 'totalTradedVolume': 0, 'impliedVolatility': 0, 'lastPrice': 105.5, 'change': 0, 'pChange': 0, 'totalBuyQuantity': 600, 'totalSellQuantity': 0, 'bidQty': 550, 'bidprice': 30.15, 'askQty': 0, 'askPrice': 0, 'underlyingValue': 20133.15}
# 32
# {'strikePrice': 15000, 'expiryDate': '31-Dec-2026', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY31-12-2026PE15000.00', 'openInterest': 44, 'changeinOpenInterest': 0, 'pchangeinOpenInterest': 0, 'totalTradedVolume': 0, 'impliedVolatility': 0, 'lastPrice': 118.9, 'change': 0, 'pChange': 0, 'totalBuyQuantity': 550, 'totalSellQuantity': 0, 'bidQty': 450, 'bidprice': 32.45, 'askQty': 0, 'askPrice': 0, 'underlyingValue': 20133.15}
# 33
# {'strikePrice': 15000, 'expiryDate': '24-Jun-2027', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY24-06-2027PE15000.00', 'openInterest': 0, 'changeinOpenInterest': 0, 'pchangeinOpenInterest': 0, 'totalTradedVolume': 0, 'impliedVolatility': 0, 'lastPrice': 0, 'change': 0, 'pChange': 0, 'totalBuyQuantity': 550, 'totalSellQuantity': 0, 'bidQty': 550, 'bidprice': 33.95, 'askQty': 0, 'askPrice': 0, 'underlyingValue': 20133.15}
# 34
# {'strikePrice': 15000, 'expiryDate': '30-Dec-2027', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY30-12-2027PE15000.00', 'openInterest': 7, 'changeinOpenInterest': 0, 'pchangeinOpenInterest': 0, 'totalTradedVolume': 0, 'impliedVolatility': 0, 'lastPrice': 86.75, 'change': 0, 'pChange': 0, 'totalBuyQuantity': 550, 'totalSellQuantity': 50, 'bidQty': 550, 'bidprice': 35.05, 'askQty': 50, 'askPrice': 100, 'underlyingValue': 20133.15}
# 35
# {'strikePrice': 15000, 'expiryDate': '29-Jun-2028', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY29-06-2028PE15000.00', 'openInterest': 0, 'changeinOpenInterest': 0, 'pchangeinOpenInterest': 0, 'totalTradedVolume': 0, 'impliedVolatility': 0, 'lastPrice': 0, 'change': 0, 'pChange': 0, 'totalBuyQuantity': 550, 'totalSellQuantity': 0, 'bidQty': 550, 'bidprice': 35.65, 'askQty': 0, 'askPrice': 0, 'underlyingValue': 20133.15}
# 36
# Key 'PE' not found in dictionary or index out of range.
# 37
# {'strikePrice': 16000, 'expiryDate': '28-Dec-2023', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY28-12-2023PE16000.00', 'openInterest': 13786, 'changeinOpenInterest': -97, 'pchangeinOpenInterest': -0.6986962472088165, 'totalTradedVolume': 2904, 'impliedVolatility': 34.12, 'lastPrice': 3.25, 'change': -0.7999999999999998, 'pChange': -19.75308641975308, 'totalBuyQuantity': 28400, 'totalSellQuantity': 9550, 'bidQty': 1700, 'bidprice': 3.25, 'askQty': 200, 'askPrice': 3.85, 'underlyingValue': 20133.15}
# 38
# {'strikePrice': 16000, 'expiryDate': '28-Mar-2024', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY28-03-2024PE16000.00', 'openInterest': 3104, 'changeinOpenInterest': -83, 'pchangeinOpenInterest': -2.6043300909946656, 'totalTradedVolume': 262, 'impliedVolatility': 22.95, 'lastPrice': 19.5, 'change': 2.3000000000000007, 'pChange': 13.372093023255818, 'totalBuyQuantity': 13450, 'totalSellQuantity': 1800, 'bidQty': 300, 'bidprice': 18.1, 'askQty': 1350, 'askPrice': 19.5, 'underlyingValue': 20133.15}
# 39
# {'strikePrice': 16000, 'expiryDate': '27-Jun-2024', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY27-06-2024PE16000.00', 'openInterest': 764, 'changeinOpenInterest': -1, 'pchangeinOpenInterest': -0.13071895424836602, 'totalTradedVolume': 14, 'impliedVolatility': 20.58, 'lastPrice': 34.95, 'change': -8.649999999999999, 'pChange': -19.8394495412844, 'totalBuyQuantity': 17850, 'totalSellQuantity': 0, 'bidQty': 8150, 'bidprice': 34.95, 'askQty': 0, 'askPrice': 0, 'underlyingValue': 20133.15}
# 40
# {'strikePrice': 16000, 'expiryDate': '26-Sep-2024', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY26-09-2024PE16000.00', 'openInterest': 0, 'changeinOpenInterest': 0, 'pchangeinOpenInterest': 0, 'totalTradedVolume': 0, 'impliedVolatility': 0, 'lastPrice': 0, 'change': 0, 'pChange': 0, 'totalBuyQuantity': 350, 'totalSellQuantity': 0, 'bidQty': 250, 'bidprice': 23.85, 'askQty': 0, 'askPrice': 0, 'underlyingValue': 20133.15}
# 41
# {'strikePrice': 16000, 'expiryDate': '26-Dec-2024', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY26-12-2024PE16000.00', 'openInterest': 388, 'changeinOpenInterest': 5, 'pchangeinOpenInterest': 1.3054830287206267, 'totalTradedVolume': 6, 'impliedVolatility': 20.47, 'lastPrice': 85.6, 'change': 1.1999999999999886, 'pChange': 1.421800947867285, 'totalBuyQuantity': 3550, 'totalSellQuantity': 1150, 'bidQty': 100, 'bidprice': 85.6, 'askQty': 500, 'askPrice': 89.95, 'underlyingValue': 20133.15}
# 42
# {'strikePrice': 16000, 'expiryDate': '26-Jun-2025', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY26-06-2025PE16000.00', 'openInterest': 2, 'changeinOpenInterest': 0, 'pchangeinOpenInterest': 0, 'totalTradedVolume': 0, 'impliedVolatility': 0, 'lastPrice': 129.2, 'change': 0, 'pChange': 0, 'totalBuyQuantity': 800, 'totalSellQuantity': 0, 'bidQty': 400, 'bidprice': 35.15, 'askQty': 0, 'askPrice': 0, 'underlyingValue': 20133.15}
# 43
# {'strikePrice': 16000, 'expiryDate': '24-Dec-2025', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY24-12-2025PE16000.00', 'openInterest': 51, 'changeinOpenInterest': 0, 'pchangeinOpenInterest': 0, 'totalTradedVolume': 0, 'impliedVolatility': 0, 'lastPrice': 79, 'change': 0, 'pChange': 0, 'totalBuyQuantity': 1050, 'totalSellQuantity': 50, 'bidQty': 450, 'bidprice': 41.65, 'askQty': 50, 'askPrice': 175, 'underlyingValue': 20133.15}
# 44
# {'strikePrice': 16000, 'expiryDate': '25-Jun-2026', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY25-06-2026PE16000.00', 'openInterest': 10, 'changeinOpenInterest': 0, 'pchangeinOpenInterest': 0, 'totalTradedVolume': 0, 'impliedVolatility': 0, 'lastPrice': 54.8, 'change': 0, 'pChange': 0, 'totalBuyQuantity': 950, 'totalSellQuantity': 0, 'bidQty': 450, 'bidprice': 46.35, 'askQty': 0, 'askPrice': 0, 'underlyingValue': 20133.15}
# 45
# {'strikePrice': 16000, 'expiryDate': '31-Dec-2026', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY31-12-2026PE16000.00', 'openInterest': 49, 'changeinOpenInterest': 0, 'pchangeinOpenInterest': 0, 'totalTradedVolume': 0, 'impliedVolatility': 0, 'lastPrice': 73.05, 'change': 0, 'pChange': 0, 'totalBuyQuantity': 750, 'totalSellQuantity': 0, 'bidQty': 450, 'bidprice': 49.55, 'askQty': 0, 'askPrice': 0, 'underlyingValue': 20133.15}
# 46
# {'strikePrice': 16000, 'expiryDate': '24-Jun-2027', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY24-06-2027PE16000.00', 'openInterest': 0, 'changeinOpenInterest': 0, 'pchangeinOpenInterest': 0, 'totalTradedVolume': 0, 'impliedVolatility': 0, 'lastPrice': 0, 'change': 0, 'pChange': 0, 'totalBuyQuantity': 450, 'totalSellQuantity': 0, 'bidQty': 450, 'bidprice': 51.25, 'askQty': 0, 'askPrice': 0, 'underlyingValue': 20133.15}
# 47
# {'strikePrice': 16000, 'expiryDate': '30-Dec-2027', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY30-12-2027PE16000.00', 'openInterest': 0, 'changeinOpenInterest': 0, 'pchangeinOpenInterest': 0, 'totalTradedVolume': 0, 'impliedVolatility': 0, 'lastPrice': 0, 'change': 0, 'pChange': 0, 'totalBuyQuantity': 450, 'totalSellQuantity': 0, 'bidQty': 450, 'bidprice': 52.1, 'askQty': 0, 'askPrice': 0, 'underlyingValue': 20133.15}
# 48
# {'strikePrice': 16000, 'expiryDate': '29-Jun-2028', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY29-06-2028PE16000.00', 'openInterest': 0, 'changeinOpenInterest': 0, 'pchangeinOpenInterest': 0, 'totalTradedVolume': 0, 'impliedVolatility': 0, 'lastPrice': 0, 'change': 0, 'pChange': 0, 'totalBuyQuantity': 450, 'totalSellQuantity': 0, 'bidQty': 450, 'bidprice': 52.05, 'askQty': 0, 'askPrice': 0, 'underlyingValue': 20133.15}
# 49
# Key 'PE' not found in dictionary or index out of range.
# 50
# {'strikePrice': 16500, 'expiryDate': '24-Dec-2025', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY24-12-2025PE16500.00', 'openInterest': 101, 'changeinOpenInterest': 0, 'pchangeinOpenInterest': 0, 'totalTradedVolume': 0, 'impliedVolatility': 0, 'lastPrice': 70, 'change': 0, 'pChange': 0, 'totalBuyQuantity': 850, 'totalSellQuantity': 50, 'bidQty': 400, 'bidprice': 54.8, 'askQty': 50, 'askPrice': 327.3, 'underlyingValue': 20133.15}
# 51
# {'strikePrice': 17000, 'expiryDate': '28-Dec-2023', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY28-12-2023PE17000.00', 'openInterest': 22597, 'changeinOpenInterest': 594, 'pchangeinOpenInterest': 2.6996318683815845, 'totalTradedVolume': 5043, 'impliedVolatility': 27.11, 'lastPrice': 4.3, 'change': -2.4000000000000004, 'pChange': -35.820895522388064, 'totalBuyQuantity': 10100, 'totalSellQuantity': 18950, 'bidQty': 1600, 'bidprice': 4.15, 'askQty': 200, 'askPrice': 4.5, 'underlyingValue': 20133.15}
# 52
# {'strikePrice': 17000, 'expiryDate': '28-Mar-2024', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY28-03-2024PE17000.00', 'openInterest': 6782, 'changeinOpenInterest': 111, 'pchangeinOpenInterest': 1.6639184530055464, 'totalTradedVolume': 726, 'impliedVolatility': 19.64, 'lastPrice': 29.2, 'change': 3.75, 'pChange': 14.734774066797643, 'totalBuyQuantity': 29900, 'totalSellQuantity': 7100, 'bidQty': 400, 'bidprice': 28.45, 'askQty': 200, 'askPrice': 30, 'underlyingValue': 20133.15}
# 53
# {'strikePrice': 17000, 'expiryDate': '27-Jun-2024', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY27-06-2024PE17000.00', 'openInterest': 2318, 'changeinOpenInterest': 95, 'pchangeinOpenInterest': 4.273504273504273, 'totalTradedVolume': 194, 'impliedVolatility': 19.65, 'lastPrice': 74.75, 'change': -0.6500000000000057, 'pChange': -0.8620689655172489, 'totalBuyQuantity': 7500, 'totalSellQuantity': 1750, 'bidQty': 50, 'bidprice': 74.75, 'askQty': 200, 'askPrice': 75.65, 'underlyingValue': 20133.15}
# 54
# {'strikePrice': 17000, 'expiryDate': '26-Sep-2024', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY26-09-2024PE17000.00', 'openInterest': 0, 'changeinOpenInterest': 0, 'pchangeinOpenInterest': 0, 'totalTradedVolume': 0, 'impliedVolatility': 0, 'lastPrice': 0, 'change': 0, 'pChange': 0, 'totalBuyQuantity': 500, 'totalSellQuantity': 0, 'bidQty': 250, 'bidprice': 38.9, 'askQty': 0, 'askPrice': 0, 'underlyingValue': 20133.15}
# 55
# {'strikePrice': 17000, 'expiryDate': '26-Dec-2024', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY26-12-2024PE17000.00', 'openInterest': 1632, 'changeinOpenInterest': 17, 'pchangeinOpenInterest': 1.0526315789473684, 'totalTradedVolume': 57, 'impliedVolatility': 19.72, 'lastPrice': 145.1, 'change': 5.75, 'pChange': 4.126300681736635, 'totalBuyQuantity': 7250, 'totalSellQuantity': 2350, 'bidQty': 50, 'bidprice': 145.1, 'askQty': 400, 'askPrice': 147.45, 'underlyingValue': 20133.15}
# 56
# {'strikePrice': 17000, 'expiryDate': '26-Jun-2025', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY26-06-2025PE17000.00', 'openInterest': 0, 'changeinOpenInterest': 0, 'pchangeinOpenInterest': 0, 'totalTradedVolume': 0, 'impliedVolatility': 0, 'lastPrice': 0, 'change': 0, 'pChange': 0, 'totalBuyQuantity': 600, 'totalSellQuantity': 0, 'bidQty': 200, 'bidprice': 63.9, 'askQty': 0, 'askPrice': 0, 'underlyingValue': 20133.15}
# 57
# {'strikePrice': 17000, 'expiryDate': '24-Dec-2025', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY24-12-2025PE17000.00', 'openInterest': 65, 'changeinOpenInterest': 1, 'pchangeinOpenInterest': 1.5625, 'totalTradedVolume': 3, 'impliedVolatility': 18.81, 'lastPrice': 168, 'change': 74.05, 'pChange': 78.81852048962213, 'totalBuyQuantity': 1450, 'totalSellQuantity': 600, 'bidQty': 250, 'bidprice': 171.05, 'askQty': 50, 'askPrice': 227.5, 'underlyingValue': 20133.15}
# 58
# {'strikePrice': 17000, 'expiryDate': '25-Jun-2026', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY25-06-2026PE17000.00', 'openInterest': 0, 'changeinOpenInterest': 0, 'pchangeinOpenInterest': 0, 'totalTradedVolume': 0, 'impliedVolatility': 0, 'lastPrice': 0, 'change': 0, 'pChange': 0, 'totalBuyQuantity': 350, 'totalSellQuantity': 0, 'bidQty': 350, 'bidprice': 83.75, 'askQty': 0, 'askPrice': 0, 'underlyingValue': 20133.15}
# 59
# {'strikePrice': 17000, 'expiryDate': '31-Dec-2026', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY31-12-2026PE17000.00', 'openInterest': 54, 'changeinOpenInterest': 0, 'pchangeinOpenInterest': 0, 'totalTradedVolume': 0, 'impliedVolatility': 0, 'lastPrice': 177.55, 'change': 0, 'pChange': 0, 'totalBuyQuantity': 750, 'totalSellQuantity': 0, 'bidQty': 350, 'bidprice': 87.6, 'askQty': 0, 'askPrice': 0, 'underlyingValue': 20133.15}
# 60
# {'strikePrice': 17000, 'expiryDate': '24-Jun-2027', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY24-06-2027PE17000.00', 'openInterest': 0, 'changeinOpenInterest': 0, 'pchangeinOpenInterest': 0, 'totalTradedVolume': 0, 'impliedVolatility': 0, 'lastPrice': 0, 'change': 0, 'pChange': 0, 'totalBuyQuantity': 350, 'totalSellQuantity': 0, 'bidQty': 350, 'bidprice': 88.35, 'askQty': 0, 'askPrice': 0, 'underlyingValue': 20133.15}
# 61
# {'strikePrice': 17000, 'expiryDate': '30-Dec-2027', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY30-12-2027PE17000.00', 'openInterest': 285, 'changeinOpenInterest': 0, 'pchangeinOpenInterest': 0, 'totalTradedVolume': 0, 'impliedVolatility': 0, 'lastPrice': 514, 'change': 0, 'pChange': 0, 'totalBuyQuantity': 650, 'totalSellQuantity': 900, 'bidQty': 650, 'bidprice': 86.95, 'askQty': 900, 'askPrice': 504.7, 'underlyingValue': 20133.15}
# 62
# {'strikePrice': 17000, 'expiryDate': '29-Jun-2028', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY29-06-2028PE17000.00', 'openInterest': 0, 'changeinOpenInterest': 0, 'pchangeinOpenInterest': 0, 'totalTradedVolume': 0, 'impliedVolatility': 0, 'lastPrice': 0, 'change': 0, 'pChange': 0, 'totalBuyQuantity': 350, 'totalSellQuantity': 0, 'bidQty': 350, 'bidprice': 84.3, 'askQty': 0, 'askPrice': 0, 'underlyingValue': 20133.15}
# 63
# {'strikePrice': 17350, 'expiryDate': '30-Nov-2023', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY30-11-2023PE17350.00', 'openInterest': 15302, 'changeinOpenInterest': -6922, 'pchangeinOpenInterest': -31.146508279337652, 'totalTradedVolume': 212445, 'impliedVolatility': 81.76, 'lastPrice': 0.05, 'change': -0.95, 'pChange': -95, 'totalBuyQuantity': 0, 'totalSellQuantity': 237900, 'bidQty': 0, 'bidprice': 0, 'askQty': 36350, 'askPrice': 0.05, 'underlyingValue': 20133.15}
# 64
# {'strikePrice': 17350, 'expiryDate': '28-Dec-2023', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY28-12-2023PE17350.00', 'openInterest': 81, 'changeinOpenInterest': -6, 'pchangeinOpenInterest': -6.896551724137931, 'totalTradedVolume': 132, 'impliedVolatility': 25.38, 'lastPrice': 5.95, 'change': -0.25, 'pChange': -4.032258064516129, 'totalBuyQuantity': 4500, 'totalSellQuantity': 0, 'bidQty': 700, 'bidprice': 4.75, 'askQty': 0, 'askPrice': 0, 'underlyingValue': 20133.15}
# 65
# {'strikePrice': 17350, 'expiryDate': '25-Jan-2024', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY25-01-2024PE17350.00', 'openInterest': 187, 'changeinOpenInterest': 0, 'pchangeinOpenInterest': 0, 'totalTradedVolume': 0, 'impliedVolatility': 0, 'lastPrice': 10.25, 'change': 0, 'pChange': 0, 'totalBuyQuantity': 85650, 'totalSellQuantity': 0, 'bidQty': 39850, 'bidprice': 3.15, 'askQty': 0, 'askPrice': 0, 'underlyingValue': 20133.15}
# 66
# {'strikePrice': 17400, 'expiryDate': '30-Nov-2023', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY30-11-2023PE17400.00', 'openInterest': 5353, 'changeinOpenInterest': -16620, 'pchangeinOpenInterest': -75.63828334774496, 'totalTradedVolume': 85119, 'impliedVolatility': 80.28, 'lastPrice': 0.05, 'change': -1.05, 'pChange': -95.45454545454545, 'totalBuyQuantity': 0, 'totalSellQuantity': 115300, 'bidQty': 0, 'bidprice': 0, 'askQty': 35250, 'askPrice': 0.05, 'underlyingValue': 20133.15}
# 67
# {'strikePrice': 17400, 'expiryDate': '28-Dec-2023', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY28-12-2023PE17400.00', 'openInterest': 406, 'changeinOpenInterest': -2, 'pchangeinOpenInterest': -0.49019607843137253, 'totalTradedVolume': 2, 'impliedVolatility': 23.75, 'lastPrice': 4.05, 'change': 1, 'pChange': 32.786885245901644, 'totalBuyQuantity': 62150, 'totalSellQuantity': 0, 'bidQty': 100, 'bidprice': 4.05, 'askQty': 0, 'askPrice': 0, 'underlyingValue': 20133.15}
# 68
# {'strikePrice': 17400, 'expiryDate': '25-Jan-2024', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY25-01-2024PE17400.00', 'openInterest': 25, 'changeinOpenInterest': 0, 'pchangeinOpenInterest': 0, 'totalTradedVolume': 0, 'impliedVolatility': 0, 'lastPrice': 23.3, 'change': 0, 'pChange': 0, 'totalBuyQuantity': 46400, 'totalSellQuantity': 0, 'bidQty': 45100, 'bidprice': 3.2, 'askQty': 0, 'askPrice': 0, 'underlyingValue': 20133.15}
# 69
# {'strikePrice': 17450, 'expiryDate': '30-Nov-2023', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY30-11-2023PE17450.00', 'openInterest': 3281, 'changeinOpenInterest': -720, 'pchangeinOpenInterest': -17.99550112471882, 'totalTradedVolume': 13845, 'impliedVolatility': 82.76, 'lastPrice': 0.1, 'change': -1.0499999999999998, 'pChange': -91.30434782608695, 'totalBuyQuantity': 12400, 'totalSellQuantity': 103850, 'bidQty': 12400, 'bidprice': 0.05, 'askQty': 1700, 'askPrice': 0.1, 'underlyingValue': 20133.15}
# 70
# {'strikePrice': 17450, 'expiryDate': '28-Dec-2023', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY28-12-2023PE17450.00', 'openInterest': 35, 'changeinOpenInterest': 0, 'pchangeinOpenInterest': 0, 'totalTradedVolume': 0, 'impliedVolatility': 0, 'lastPrice': 6, 'change': 0, 'pChange': 0, 'totalBuyQuantity': 44250, 'totalSellQuantity': 0, 'bidQty': 43200, 'bidprice': 3.05, 'askQty': 0, 'askPrice': 0, 'underlyingValue': 20133.15}
# 71
# {'strikePrice': 17450, 'expiryDate': '25-Jan-2024', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY25-01-2024PE17450.00', 'openInterest': 43, 'changeinOpenInterest': 0, 'pchangeinOpenInterest': 0, 'totalTradedVolume': 0, 'impliedVolatility': 0, 'lastPrice': 19.1, 'change': 0.05000000000000071, 'pChange': 0.2624671916010536, 'totalBuyQuantity': 40850, 'totalSellQuantity': 0, 'bidQty': 39600, 'bidprice': 3.25, 'askQty': 0, 'askPrice': 0, 'underlyingValue': 20133.15}
# 72
# {'strikePrice': 17500, 'expiryDate': '30-Nov-2023', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY30-11-2023PE17500.00', 'openInterest': 14919, 'changeinOpenInterest': -16872, 'pchangeinOpenInterest': -53.07162404454091, 'totalTradedVolume': 117630, 'impliedVolatility': 77.33, 'lastPrice': 0.05, 'change': -1.0999999999999999, 'pChange': -95.65217391304347, 'totalBuyQuantity': 0, 'totalSellQuantity': 226000, 'bidQty': 0, 'bidprice': 0, 'askQty': 77400, 'askPrice': 0.05, 'underlyingValue': 20133.15}
# 73
# {'strikePrice': 17500, 'expiryDate': '28-Dec-2023', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY28-12-2023PE17500.00', 'openInterest': 22783, 'changeinOpenInterest': 271, 'pchangeinOpenInterest': 1.2038024164889836, 'totalTradedVolume': 8768, 'impliedVolatility': 24.35, 'lastPrice': 6.3, 'change': -2.1499999999999995, 'pChange': -25.44378698224852, 'totalBuyQuantity': 12000, 'totalSellQuantity': 1000, 'bidQty': 3500, 'bidprice': 6.3, 'askQty': 350, 'askPrice': 7, 'underlyingValue': 20133.15}
# 74
# {'strikePrice': 17500, 'expiryDate': '25-Jan-2024', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY25-01-2024PE17500.00', 'openInterest': 4961, 'changeinOpenInterest': 23, 'pchangeinOpenInterest': 0.46577561765897124, 'totalTradedVolume': 169, 'impliedVolatility': 20.71, 'lastPrice': 15.95, 'change': -0.15000000000000213, 'pChange': -0.9316770186335536, 'totalBuyQuantity': 2850, 'totalSellQuantity': 250, 'bidQty': 100, 'bidprice': 14.25, 'askQty': 50, 'askPrice': 16, 'underlyingValue': 20133.15}
# 75
# {'strikePrice': 17550, 'expiryDate': '30-Nov-2023', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY30-11-2023PE17550.00', 'openInterest': 261, 'changeinOpenInterest': -370, 'pchangeinOpenInterest': -58.63708399366086, 'totalTradedVolume': 5698, 'impliedVolatility': 79.68, 'lastPrice': 0.1, 'change': -1.0499999999999998, 'pChange': -91.30434782608695, 'totalBuyQuantity': 0, 'totalSellQuantity': 97700, 'bidQty': 0, 'bidprice': 0, 'askQty': 1950, 'askPrice': 0.15, 'underlyingValue': 20133.15}
# 76
# {'strikePrice': 17550, 'expiryDate': '28-Dec-2023', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY28-12-2023PE17550.00', 'openInterest': 75, 'changeinOpenInterest': 4, 'pchangeinOpenInterest': 5.633802816901408, 'totalTradedVolume': 19, 'impliedVolatility': 23.81, 'lastPrice': 6.05, 'change': 3, 'pChange': 98.36065573770493, 'totalBuyQuantity': 5400, 'totalSellQuantity': 0, 'bidQty': 1800, 'bidprice': 3.3, 'askQty': 0, 'askPrice': 0, 'underlyingValue': 20133.15}
# 77
# {'strikePrice': 17550, 'expiryDate': '25-Jan-2024', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY25-01-2024PE17550.00', 'openInterest': 8, 'changeinOpenInterest': 0, 'pchangeinOpenInterest': 0, 'totalTradedVolume': 0, 'impliedVolatility': 0, 'lastPrice': 28.85, 'change': 0, 'pChange': 0, 'totalBuyQuantity': 44750, 'totalSellQuantity': 0, 'bidQty': 42300, 'bidprice': 3.35, 'askQty': 0, 'askPrice': 0, 'underlyingValue': 20133.15}
# 78
# {'strikePrice': 17600, 'expiryDate': '30-Nov-2023', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY30-11-2023PE17600.00', 'openInterest': 2406, 'changeinOpenInterest': -1935, 'pchangeinOpenInterest': -44.574982722874914, 'totalTradedVolume': 10569, 'impliedVolatility': 74.39, 'lastPrice': 0.05, 'change': -1.0999999999999999, 'pChange': -95.65217391304347, 'totalBuyQuantity': 0, 'totalSellQuantity': 103600, 'bidQty': 0, 'bidprice': 0, 'askQty': 1800, 'askPrice': 0.1, 'underlyingValue': 20133.15}
# 79
# {'strikePrice': 17600, 'expiryDate': '28-Dec-2023', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY28-12-2023PE17600.00', 'openInterest': 235, 'changeinOpenInterest': -11, 'pchangeinOpenInterest': -4.471544715447155, 'totalTradedVolume': 240, 'impliedVolatility': 23.5, 'lastPrice': 6.25, 'change': -1.1500000000000004, 'pChange': -15.540540540540546, 'totalBuyQuantity': 2600, 'totalSellQuantity': 50, 'bidQty': 1700, 'bidprice': 6.25, 'askQty': 50, 'askPrice': 9.9, 'underlyingValue': 20133.15}
# 80
# {'strikePrice': 17600, 'expiryDate': '25-Jan-2024', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY25-01-2024PE17600.00', 'openInterest': 15, 'changeinOpenInterest': 0, 'pchangeinOpenInterest': 0, 'totalTradedVolume': 0, 'impliedVolatility': 0, 'lastPrice': 28.2, 'change': 0, 'pChange': 0, 'totalBuyQuantity': 37800, 'totalSellQuantity': 0, 'bidQty': 37800, 'bidprice': 3.7, 'askQty': 0, 'askPrice': 0, 'underlyingValue': 20133.15}
# 81
# {'strikePrice': 17650, 'expiryDate': '30-Nov-2023', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY30-11-2023PE17650.00', 'openInterest': 320, 'changeinOpenInterest': -751, 'pchangeinOpenInterest': -70.12138188608778, 'totalTradedVolume': 9461, 'impliedVolatility': 72.92, 'lastPrice': 0.05, 'change': -1.0999999999999999, 'pChange': -95.65217391304347, 'totalBuyQuantity': 0, 'totalSellQuantity': 129600, 'bidQty': 0, 'bidprice': 0, 'askQty': 3950, 'askPrice': 0.05, 'underlyingValue': 20133.15}
# 82
# {'strikePrice': 17650, 'expiryDate': '07-Dec-2023', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY07-12-2023PE17650.00', 'openInterest': 2301, 'changeinOpenInterest': 279, 'pchangeinOpenInterest': 13.798219584569733, 'totalTradedVolume': 5237, 'impliedVolatility': 37.32, 'lastPrice': 1.5, 'change': -0.5499999999999998, 'pChange': -26.829268292682922, 'totalBuyQuantity': 242850, 'totalSellQuantity': 17150, 'bidQty': 150, 'bidprice': 1.35, 'askQty': 3000, 'askPrice': 1.5, 'underlyingValue': 20133.15}
# 83
# {'strikePrice': 17650, 'expiryDate': '28-Dec-2023', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY28-12-2023PE17650.00', 'openInterest': 53, 'changeinOpenInterest': 0, 'pchangeinOpenInterest': 0, 'totalTradedVolume': 0, 'impliedVolatility': 0, 'lastPrice': 12.4, 'change': 0, 'pChange': 0, 'totalBuyQuantity': 50300, 'totalSellQuantity': 0, 'bidQty': 45000, 'bidprice': 3.05, 'askQty': 0, 'askPrice': 0, 'underlyingValue': 20133.15}
# 84
# {'strikePrice': 17650, 'expiryDate': '25-Jan-2024', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY25-01-2024PE17650.00', 'openInterest': 19, 'changeinOpenInterest': 0, 'pchangeinOpenInterest': 0, 'totalTradedVolume': 0, 'impliedVolatility': 0, 'lastPrice': 29, 'change': 0, 'pChange': 0, 'totalBuyQuantity': 39600, 'totalSellQuantity': 0, 'bidQty': 39600, 'bidprice': 4.3, 'askQty': 0, 'askPrice': 0, 'underlyingValue': 20133.15}
# 85
# {'strikePrice': 17700, 'expiryDate': '30-Nov-2023', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY30-11-2023PE17700.00', 'openInterest': 1875, 'changeinOpenInterest': -146, 'pchangeinOpenInterest': -7.224146462147452, 'totalTradedVolume': 8987, 'impliedVolatility': 71.45, 'lastPrice': 0.05, 'change': -1.0999999999999999, 'pChange': -95.65217391304347, 'totalBuyQuantity': 0, 'totalSellQuantity': 112150, 'bidQty': 0, 'bidprice': 0, 'askQty': 22650, 'askPrice': 0.05, 'underlyingValue': 20133.15}
# 86
# {'strikePrice': 17700, 'expiryDate': '07-Dec-2023', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY07-12-2023PE17700.00', 'openInterest': 845, 'changeinOpenInterest': 703, 'pchangeinOpenInterest': 495.07042253521126, 'totalTradedVolume': 1889, 'impliedVolatility': 37.59, 'lastPrice': 1.9, 'change': -0.4500000000000002, 'pChange': -19.148936170212774, 'totalBuyQuantity': 33100, 'totalSellQuantity': 4150, 'bidQty': 50, 'bidprice': 1.4, 'askQty': 500, 'askPrice': 2.9, 'underlyingValue': 20133.15}
# 87
# {'strikePrice': 17700, 'expiryDate': '28-Dec-2023', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY28-12-2023PE17700.00', 'openInterest': 366, 'changeinOpenInterest': -5, 'pchangeinOpenInterest': -1.3477088948787062, 'totalTradedVolume': 5, 'impliedVolatility': 22.58, 'lastPrice': 6.05, 'change': 3, 'pChange': 98.36065573770493, 'totalBuyQuantity': 22450, 'totalSellQuantity': 0, 'bidQty': 1850, 'bidprice': 6.05, 'askQty': 0, 'askPrice': 0, 'underlyingValue': 20133.15}
# 88
# {'strikePrice': 17700, 'expiryDate': '25-Jan-2024', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY25-01-2024PE17700.00', 'openInterest': 64, 'changeinOpenInterest': 0, 'pchangeinOpenInterest': 0, 'totalTradedVolume': 0, 'impliedVolatility': 0, 'lastPrice': 18.15, 'change': 0, 'pChange': 0, 'totalBuyQuantity': 37800, 'totalSellQuantity': 0, 'bidQty': 37500, 'bidprice': 5, 'askQty': 0, 'askPrice': 0, 'underlyingValue': 20133.15}
# 89
# {'strikePrice': 17750, 'expiryDate': '30-Nov-2023', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY30-11-2023PE17750.00', 'openInterest': 2995, 'changeinOpenInterest': -558, 'pchangeinOpenInterest': -15.705037996059668, 'totalTradedVolume': 9574, 'impliedVolatility': 69.99, 'lastPrice': 0.05, 'change': -1.15, 'pChange': -95.83333333333333, 'totalBuyQuantity': 0, 'totalSellQuantity': 98750, 'bidQty': 0, 'bidprice': 0, 'askQty': 250, 'askPrice': 0.1, 'underlyingValue': 20133.15}
# 90
# {'strikePrice': 17750, 'expiryDate': '07-Dec-2023', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY07-12-2023PE17750.00', 'openInterest': 208, 'changeinOpenInterest': 157, 'pchangeinOpenInterest': 307.84313725490193, 'totalTradedVolume': 360, 'impliedVolatility': 35.9, 'lastPrice': 1.5, 'change': -1.1, 'pChange': -42.30769230769231, 'totalBuyQuantity': 69900, 'totalSellQuantity': 3800, 'bidQty': 1500, 'bidprice': 1.1, 'askQty': 750, 'askPrice': 1.6, 'underlyingValue': 20133.15}
# 91
# {'strikePrice': 17750, 'expiryDate': '28-Dec-2023', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY28-12-2023PE17750.00', 'openInterest': 62, 'changeinOpenInterest': 6, 'pchangeinOpenInterest': 10.714285714285714, 'totalTradedVolume': 6, 'impliedVolatility': 20.27, 'lastPrice': 3.05, 'change': -8.95, 'pChange': -74.58333333333333, 'totalBuyQuantity': 55700, 'totalSellQuantity': 0, 'bidQty': 53850, 'bidprice': 3.05, 'askQty': 0, 'askPrice': 0, 'underlyingValue': 20133.15}
# 92
# {'strikePrice': 17750, 'expiryDate': '25-Jan-2024', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY25-01-2024PE17750.00', 'openInterest': 32, 'changeinOpenInterest': 0, 'pchangeinOpenInterest': 0, 'totalTradedVolume': 0, 'impliedVolatility': 0, 'lastPrice': 14.4, 'change': 0, 'pChange': 0, 'totalBuyQuantity': 37850, 'totalSellQuantity': 0, 'bidQty': 37800, 'bidprice': 5.7, 'askQty': 0, 'askPrice': 0, 'underlyingValue': 20133.15}
# 93
# {'strikePrice': 17800, 'expiryDate': '30-Nov-2023', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY30-11-2023PE17800.00', 'openInterest': 4496, 'changeinOpenInterest': -19783, 'pchangeinOpenInterest': -81.48193912434614, 'totalTradedVolume': 72972, 'impliedVolatility': 68.53, 'lastPrice': 0.05, 'change': -1.3, 'pChange': -96.29629629629629, 'totalBuyQuantity': 0, 'totalSellQuantity': 109200, 'bidQty': 0, 'bidprice': 0, 'askQty': 600, 'askPrice': 0.05, 'underlyingValue': 20133.15}
# 94
# {'strikePrice': 17800, 'expiryDate': '07-Dec-2023', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY07-12-2023PE17800.00', 'openInterest': 1051, 'changeinOpenInterest': 832, 'pchangeinOpenInterest': 379.9086757990868, 'totalTradedVolume': 2113, 'impliedVolatility': 35.69, 'lastPrice': 1.7, 'change': -0.5999999999999999, 'pChange': -26.086956521739125, 'totalBuyQuantity': 75750, 'totalSellQuantity': 21800, 'bidQty': 1250, 'bidprice': 1.45, 'askQty': 1150, 'askPrice': 1.7, 'underlyingValue': 20133.15}
# 95
# {'strikePrice': 17800, 'expiryDate': '28-Dec-2023', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY28-12-2023PE17800.00', 'openInterest': 650, 'changeinOpenInterest': -29, 'pchangeinOpenInterest': -4.270986745213549, 'totalTradedVolume': 618, 'impliedVolatility': 22.25, 'lastPrice': 7.05, 'change': -1.6000000000000005, 'pChange': -18.4971098265896, 'totalBuyQuantity': 0, 'totalSellQuantity': 50, 'bidQty': 0, 'bidprice': 0, 'askQty': 50, 'askPrice': 6.8, 'underlyingValue': 20133.15}
# 96
# {'strikePrice': 17800, 'expiryDate': '25-Jan-2024', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY25-01-2024PE17800.00', 'openInterest': 33, 'changeinOpenInterest': 0, 'pchangeinOpenInterest': 0, 'totalTradedVolume': 0, 'impliedVolatility': 0, 'lastPrice': 14.65, 'change': 0, 'pChange': 0, 'totalBuyQuantity': 38350, 'totalSellQuantity': 0, 'bidQty': 37800, 'bidprice': 6.6, 'askQty': 0, 'askPrice': 0, 'underlyingValue': 20133.15}
# 97
# {'strikePrice': 17850, 'expiryDate': '30-Nov-2023', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY30-11-2023PE17850.00', 'openInterest': 382, 'changeinOpenInterest': -564, 'pchangeinOpenInterest': -59.61945031712474, 'totalTradedVolume': 4504, 'impliedVolatility': 67.07, 'lastPrice': 0.05, 'change': -1.2, 'pChange': -96, 'totalBuyQuantity': 0, 'totalSellQuantity': 102200, 'bidQty': 0, 'bidprice': 0, 'askQty': 3200, 'askPrice': 0.05, 'underlyingValue': 20133.15}
# 98
# {'strikePrice': 17850, 'expiryDate': '07-Dec-2023', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY07-12-2023PE17850.00', 'openInterest': 214, 'changeinOpenInterest': 209, 'pchangeinOpenInterest': 4180, 'totalTradedVolume': 631, 'impliedVolatility': 34.73, 'lastPrice': 1.6, 'change': -1.25, 'pChange': -43.859649122807014, 'totalBuyQuantity': 10750, 'totalSellQuantity': 3200, 'bidQty': 1800, 'bidprice': 1.2, 'askQty': 100, 'askPrice': 1.9, 'underlyingValue': 20133.15}
# 99
# {'strikePrice': 17850, 'expiryDate': '28-Dec-2023', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY28-12-2023PE17850.00', 'openInterest': 125, 'changeinOpenInterest': -296, 'pchangeinOpenInterest': -70.30878859857482, 'totalTradedVolume': 618, 'impliedVolatility': 21.86, 'lastPrice': 7.1, 'change': -1.5, 'pChange': -17.441860465116278, 'totalBuyQuantity': 0, 'totalSellQuantity': 100, 'bidQty': 0, 'bidprice': 0, 'askQty': 100, 'askPrice': 7.5, 'underlyingValue': 20133.15}
# 100
# {'strikePrice': 17850, 'expiryDate': '25-Jan-2024', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY25-01-2024PE17850.00', 'openInterest': 20, 'changeinOpenInterest': 0, 'pchangeinOpenInterest': 0, 'totalTradedVolume': 0, 'impliedVolatility': 0, 'lastPrice': 17.25, 'change': 0, 'pChange': 0, 'totalBuyQuantity': 40050, 'totalSellQuantity': 0, 'bidQty': 39600, 'bidprice': 7.55, 'askQty': 0, 'askPrice': 0, 'underlyingValue': 20133.15}
# 101
# {'strikePrice': 17900, 'expiryDate': '30-Nov-2023', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY30-11-2023PE17900.00', 'openInterest': 3655, 'changeinOpenInterest': -21438, 'pchangeinOpenInterest': -85.43418483242338, 'totalTradedVolume': 82157, 'impliedVolatility': 65.62, 'lastPrice': 0.05, 'change': -1.3, 'pChange': -96.29629629629629, 'totalBuyQuantity': 0, 'totalSellQuantity': 110000, 'bidQty': 0, 'bidprice': 0, 'askQty': 100, 'askPrice': 0.05, 'underlyingValue': 20133.15}
# 102
# {'strikePrice': 17900, 'expiryDate': '07-Dec-2023', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY07-12-2023PE17900.00', 'openInterest': 464, 'changeinOpenInterest': 324, 'pchangeinOpenInterest': 231.42857142857142, 'totalTradedVolume': 1109, 'impliedVolatility': 34.59, 'lastPrice': 1.85, 'change': -1.0499999999999998, 'pChange': -36.206896551724135, 'totalBuyQuantity': 11100, 'totalSellQuantity': 4700, 'bidQty': 1500, 'bidprice': 1.4, 'askQty': 100, 'askPrice': 1.9, 'underlyingValue': 20133.15}
# 103
# {'strikePrice': 17900, 'expiryDate': '14-Dec-2023', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY14-12-2023PE17900.00', 'openInterest': 0, 'changeinOpenInterest': 0, 'pchangeinOpenInterest': 0, 'totalTradedVolume': 0, 'impliedVolatility': 0, 'lastPrice': 0, 'change': 0, 'pChange': 0, 'totalBuyQuantity': 29250, 'totalSellQuantity': 0, 'bidQty': 1800, 'bidprice': 1.6, 'askQty': 0, 'askPrice': 0, 'underlyingValue': 20133.15}
# 104
# {'strikePrice': 17900, 'expiryDate': '28-Dec-2023', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY28-12-2023PE17900.00', 'openInterest': 490, 'changeinOpenInterest': -37, 'pchangeinOpenInterest': -7.020872865275142, 'totalTradedVolume': 1040, 'impliedVolatility': 21.4, 'lastPrice': 7, 'change': -1.9000000000000004, 'pChange': -21.348314606741575, 'totalBuyQuantity': 3350, 'totalSellQuantity': 1900, 'bidQty': 1800, 'bidprice': 6.35, 'askQty': 1800, 'askPrice': 8.25, 'underlyingValue': 20133.15}
# 105
# ...
# 673
# {'strikePrice': 23000, 'expiryDate': '28-Dec-2023', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY28-12-2023PE23000.00', 'openInterest': 11328, 'changeinOpenInterest': 698, 'pchangeinOpenInterest': 6.566321730950141, 'totalTradedVolume': 2331, 'impliedVolatility': 15.35, 'lastPrice': 2691.5, 'change': -21.949999999999818, 'pChange': -0.8089332768246998, 'totalBuyQuantity': 4000, 'totalSellQuantity': 3600, 'bidQty': 50, 'bidprice': 2688, 'askQty': 50, 'askPrice': 2701.05, 'underlyingValue': 20133.15}
# 674
# {'strikePrice': 23000, 'expiryDate': '28-Mar-2024', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY28-03-2024PE23000.00', 'openInterest': 0, 'changeinOpenInterest': 0, 'pchangeinOpenInterest': 0, 'totalTradedVolume': 0, 'impliedVolatility': 0, 'lastPrice': 0, 'change': 0, 'pChange': 0, 'totalBuyQuantity': 50, 'totalSellQuantity': 0, 'bidQty': 50, 'bidprice': 1610.05, 'askQty': 0, 'askPrice': 0, 'underlyingValue': 20133.15}
# 675
# {'strikePrice': 23000, 'expiryDate': '27-Jun-2024', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY27-06-2024PE23000.00', 'openInterest': 0, 'changeinOpenInterest': 0, 'pchangeinOpenInterest': 0, 'totalTradedVolume': 0, 'impliedVolatility': 0, 'lastPrice': 0, 'change': 0, 'pChange': 0, 'totalBuyQuantity': 50, 'totalSellQuantity': 0, 'bidQty': 50, 'bidprice': 1325.05, 'askQty': 0, 'askPrice': 0, 'underlyingValue': 20133.15}
# 676
# {'strikePrice': 23000, 'expiryDate': '26-Sep-2024', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY26-09-2024PE23000.00', 'openInterest': 0, 'changeinOpenInterest': 0, 'pchangeinOpenInterest': 0, 'totalTradedVolume': 0, 'impliedVolatility': 0, 'lastPrice': 0, 'change': 0, 'pChange': 0, 'totalBuyQuantity': 50, 'totalSellQuantity': 0, 'bidQty': 50, 'bidprice': 1225.05, 'askQty': 0, 'askPrice': 0, 'underlyingValue': 20133.15}
# 677
# {'strikePrice': 23000, 'expiryDate': '26-Dec-2024', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY26-12-2024PE23000.00', 'openInterest': 90, 'changeinOpenInterest': 1, 'pchangeinOpenInterest': 1.1235955056179776, 'totalTradedVolume': 1, 'impliedVolatility': 19.05, 'lastPrice': 1880.05, 'change': -9.950000000000045, 'pChange': -0.5264550264550288, 'totalBuyQuantity': 100, 'totalSellQuantity': 650, 'bidQty': 50, 'bidprice': 1860, 'askQty': 50, 'askPrice': 2052.85, 'underlyingValue': 20133.15}
# 678
# {'strikePrice': 23000, 'expiryDate': '26-Jun-2025', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY26-06-2025PE23000.00', 'openInterest': 0, 'changeinOpenInterest': 0, 'pchangeinOpenInterest': 0, 'totalTradedVolume': 0, 'impliedVolatility': 0, 'lastPrice': 0, 'change': 0, 'pChange': 0, 'totalBuyQuantity': 50, 'totalSellQuantity': 0, 'bidQty': 50, 'bidprice': 975.05, 'askQty': 0, 'askPrice': 0, 'underlyingValue': 20133.15}
# 679
# {'strikePrice': 23000, 'expiryDate': '24-Dec-2025', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY24-12-2025PE23000.00', 'openInterest': 0, 'changeinOpenInterest': 0, 'pchangeinOpenInterest': 0, 'totalTradedVolume': 0, 'impliedVolatility': 0, 'lastPrice': 0, 'change': 0, 'pChange': 0, 'totalBuyQuantity': 2350, 'totalSellQuantity': 0, 'bidQty': 250, 'bidprice': 850.05, 'askQty': 0, 'askPrice': 0, 'underlyingValue': 20133.15}
# 680
# {'strikePrice': 23000, 'expiryDate': '25-Jun-2026', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY25-06-2026PE23000.00', 'openInterest': 0, 'changeinOpenInterest': 0, 'pchangeinOpenInterest': 0, 'totalTradedVolume': 0, 'impliedVolatility': 0, 'lastPrice': 0, 'change': 0, 'pChange': 0, 'totalBuyQuantity': 2050, 'totalSellQuantity': 0, 'bidQty': 250, 'bidprice': 730.05, 'askQty': 0, 'askPrice': 0, 'underlyingValue': 20133.15}
# 681
# {'strikePrice': 23000, 'expiryDate': '31-Dec-2026', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY31-12-2026PE23000.00', 'openInterest': 52, 'changeinOpenInterest': 0, 'pchangeinOpenInterest': 0, 'totalTradedVolume': 0, 'impliedVolatility': 0, 'lastPrice': 1615, 'change': 0, 'pChange': 0, 'totalBuyQuantity': 2400, 'totalSellQuantity': 250, 'bidQty': 50, 'bidprice': 916, 'askQty': 50, 'askPrice': 1799.95, 'underlyingValue': 20133.15}
# 682
# {'strikePrice': 23000, 'expiryDate': '24-Jun-2027', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY24-06-2027PE23000.00', 'openInterest': 0, 'changeinOpenInterest': 0, 'pchangeinOpenInterest': 0, 'totalTradedVolume': 0, 'impliedVolatility': 0, 'lastPrice': 0, 'change': 0, 'pChange': 0, 'totalBuyQuantity': 2050, 'totalSellQuantity': 0, 'bidQty': 250, 'bidprice': 590.05, 'askQty': 0, 'askPrice': 0, 'underlyingValue': 20133.15}
# 683
# {'strikePrice': 23000, 'expiryDate': '30-Dec-2027', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY30-12-2027PE23000.00', 'openInterest': 0, 'changeinOpenInterest': 0, 'pchangeinOpenInterest': 0, 'totalTradedVolume': 0, 'impliedVolatility': 0, 'lastPrice': 0, 'change': 0, 'pChange': 0, 'totalBuyQuantity': 2050, 'totalSellQuantity': 0, 'bidQty': 250, 'bidprice': 510.05, 'askQty': 0, 'askPrice': 0, 'underlyingValue': 20133.15}
# 684
# {'strikePrice': 23000, 'expiryDate': '29-Jun-2028', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY29-06-2028PE23000.00', 'openInterest': 0, 'changeinOpenInterest': 0, 'pchangeinOpenInterest': 0, 'totalTradedVolume': 0, 'impliedVolatility': 0, 'lastPrice': 0, 'change': 0, 'pChange': 0, 'totalBuyQuantity': 2050, 'totalSellQuantity': 0, 'bidQty': 250, 'bidprice': 460.05, 'askQty': 0, 'askPrice': 0, 'underlyingValue': 20133.15}
# 685
# {'strikePrice': 24000, 'expiryDate': '28-Dec-2023', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY28-12-2023PE24000.00', 'openInterest': 16, 'changeinOpenInterest': 0, 'pchangeinOpenInterest': 0, 'totalTradedVolume': 0, 'impliedVolatility': 0, 'lastPrice': 3692.4, 'change': 0.650000000000091, 'pChange': 0.017606826031017566, 'totalBuyQuantity': 2100, 'totalSellQuantity': 2150, 'bidQty': 350, 'bidprice': 3632.15, 'askQty': 2150, 'askPrice': 3994.35, 'underlyingValue': 20133.15}
# 686
# {'strikePrice': 24000, 'expiryDate': '28-Mar-2024', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY28-03-2024PE24000.00', 'openInterest': 8, 'changeinOpenInterest': 1, 'pchangeinOpenInterest': 14.285714285714286, 'totalTradedVolume': 1, 'impliedVolatility': 21.27, 'lastPrice': 3250.95, 'change': 0, 'pChange': 0, 'totalBuyQuantity': 50, 'totalSellQuantity': 0, 'bidQty': 50, 'bidprice': 2490.05, 'askQty': 0, 'askPrice': 0, 'underlyingValue': 20133.15}
# 687
# {'strikePrice': 24000, 'expiryDate': '27-Jun-2024', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY27-06-2024PE24000.00', 'openInterest': 0, 'changeinOpenInterest': 0, 'pchangeinOpenInterest': 0, 'totalTradedVolume': 0, 'impliedVolatility': 0, 'lastPrice': 0, 'change': 0, 'pChange': 0, 'totalBuyQuantity': 50, 'totalSellQuantity': 0, 'bidQty': 50, 'bidprice': 2075.05, 'askQty': 0, 'askPrice': 0, 'underlyingValue': 20133.15}
# 688
# {'strikePrice': 24000, 'expiryDate': '26-Sep-2024', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY26-09-2024PE24000.00', 'openInterest': 0, 'changeinOpenInterest': 0, 'pchangeinOpenInterest': 0, 'totalTradedVolume': 0, 'impliedVolatility': 0, 'lastPrice': 0, 'change': 0, 'pChange': 0, 'totalBuyQuantity': 50, 'totalSellQuantity': 0, 'bidQty': 50, 'bidprice': 1700.05, 'askQty': 0, 'askPrice': 0, 'underlyingValue': 20133.15}
# 689
# {'strikePrice': 24000, 'expiryDate': '26-Dec-2024', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY26-12-2024PE24000.00', 'openInterest': 0, 'changeinOpenInterest': 0, 'pchangeinOpenInterest': 0, 'totalTradedVolume': 0, 'impliedVolatility': 0, 'lastPrice': 0, 'change': 0, 'pChange': 0, 'totalBuyQuantity': 150, 'totalSellQuantity': 0, 'bidQty': 50, 'bidprice': 2475.05, 'askQty': 0, 'askPrice': 0, 'underlyingValue': 20133.15}
# 690
# {'strikePrice': 24000, 'expiryDate': '26-Jun-2025', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY26-06-2025PE24000.00', 'openInterest': 0, 'changeinOpenInterest': 0, 'pchangeinOpenInterest': 0, 'totalTradedVolume': 0, 'impliedVolatility': 0, 'lastPrice': 0, 'change': 0, 'pChange': 0, 'totalBuyQuantity': 50, 'totalSellQuantity': 0, 'bidQty': 50, 'bidprice': 1325.05, 'askQty': 0, 'askPrice': 0, 'underlyingValue': 20133.15}
# 691
# {'strikePrice': 24000, 'expiryDate': '24-Dec-2025', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY24-12-2025PE24000.00', 'openInterest': 0, 'changeinOpenInterest': 0, 'pchangeinOpenInterest': 0, 'totalTradedVolume': 0, 'impliedVolatility': 0, 'lastPrice': 0, 'change': 0, 'pChange': 0, 'totalBuyQuantity': 50, 'totalSellQuantity': 0, 'bidQty': 50, 'bidprice': 1150.05, 'askQty': 0, 'askPrice': 0, 'underlyingValue': 20133.15}
# 692
# {'strikePrice': 24000, 'expiryDate': '25-Jun-2026', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY25-06-2026PE24000.00', 'openInterest': 0, 'changeinOpenInterest': 0, 'pchangeinOpenInterest': 0, 'totalTradedVolume': 0, 'impliedVolatility': 0, 'lastPrice': 0, 'change': 0, 'pChange': 0, 'totalBuyQuantity': 1850, 'totalSellQuantity': 0, 'bidQty': 50, 'bidprice': 1025.05, 'askQty': 0, 'askPrice': 0, 'underlyingValue': 20133.15}
# 693
# {'strikePrice': 24000, 'expiryDate': '31-Dec-2026', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY31-12-2026PE24000.00', 'openInterest': 0, 'changeinOpenInterest': 0, 'pchangeinOpenInterest': 0, 'totalTradedVolume': 0, 'impliedVolatility': 0, 'lastPrice': 0, 'change': 0, 'pChange': 0, 'totalBuyQuantity': 2350, 'totalSellQuantity': 0, 'bidQty': 250, 'bidprice': 880.05, 'askQty': 0, 'askPrice': 0, 'underlyingValue': 20133.15}
# 694
# {'strikePrice': 24000, 'expiryDate': '24-Jun-2027', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY24-06-2027PE24000.00', 'openInterest': 0, 'changeinOpenInterest': 0, 'pchangeinOpenInterest': 0, 'totalTradedVolume': 0, 'impliedVolatility': 0, 'lastPrice': 0, 'change': 0, 'pChange': 0, 'totalBuyQuantity': 1850, 'totalSellQuantity': 0, 'bidQty': 50, 'bidprice': 775.05, 'askQty': 0, 'askPrice': 0, 'underlyingValue': 20133.15}
# 695
# {'strikePrice': 24000, 'expiryDate': '30-Dec-2027', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY30-12-2027PE24000.00', 'openInterest': 0, 'changeinOpenInterest': 0, 'pchangeinOpenInterest': 0, 'totalTradedVolume': 0, 'impliedVolatility': 0, 'lastPrice': 0, 'change': 0, 'pChange': 0, 'totalBuyQuantity': 2050, 'totalSellQuantity': 0, 'bidQty': 250, 'bidprice': 675.05, 'askQty': 0, 'askPrice': 0, 'underlyingValue': 20133.15}
# 696
# {'strikePrice': 24000, 'expiryDate': '29-Jun-2028', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY29-06-2028PE24000.00', 'openInterest': 0, 'changeinOpenInterest': 0, 'pchangeinOpenInterest': 0, 'totalTradedVolume': 0, 'impliedVolatility': 0, 'lastPrice': 0, 'change': 0, 'pChange': 0, 'totalBuyQuantity': 2050, 'totalSellQuantity': 0, 'bidQty': 250, 'bidprice': 605.05, 'askQty': 0, 'askPrice': 0, 'underlyingValue': 20133.15}
# 697
# {'strikePrice': 25000, 'expiryDate': '28-Dec-2023', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY28-12-2023PE25000.00', 'openInterest': 0, 'changeinOpenInterest': 0, 'pchangeinOpenInterest': 0, 'totalTradedVolume': 0, 'impliedVolatility': 0, 'lastPrice': 0, 'change': 0, 'pChange': 0, 'totalBuyQuantity': 2050, 'totalSellQuantity': 2050, 'bidQty': 2050, 'bidprice': 4562.75, 'askQty': 300, 'askPrice': 5027.9, 'underlyingValue': 20133.15}
# 698
# {'strikePrice': 25000, 'expiryDate': '28-Mar-2024', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY28-03-2024PE25000.00', 'openInterest': 0, 'changeinOpenInterest': 0, 'pchangeinOpenInterest': 0, 'totalTradedVolume': 0, 'impliedVolatility': 0, 'lastPrice': 0, 'change': 0, 'pChange': 0, 'totalBuyQuantity': 50, 'totalSellQuantity': 0, 'bidQty': 50, 'bidprice': 3630.05, 'askQty': 0, 'askPrice': 0, 'underlyingValue': 20133.15}
# 699
# {'strikePrice': 25000, 'expiryDate': '27-Jun-2024', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY27-06-2024PE25000.00', 'openInterest': 0, 'changeinOpenInterest': 0, 'pchangeinOpenInterest': 0, 'totalTradedVolume': 0, 'impliedVolatility': 0, 'lastPrice': 0, 'change': 0, 'pChange': 0, 'totalBuyQuantity': 50, 'totalSellQuantity': 0, 'bidQty': 50, 'bidprice': 3070.05, 'askQty': 0, 'askPrice': 0, 'underlyingValue': 20133.15}
# 700
# {'strikePrice': 25000, 'expiryDate': '26-Sep-2024', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY26-09-2024PE25000.00', 'openInterest': 0, 'changeinOpenInterest': 0, 'pchangeinOpenInterest': 0, 'totalTradedVolume': 0, 'impliedVolatility': 0, 'lastPrice': 0, 'change': 0, 'pChange': 0, 'totalBuyQuantity': 50, 'totalSellQuantity': 0, 'bidQty': 50, 'bidprice': 2525.05, 'askQty': 0, 'askPrice': 0, 'underlyingValue': 20133.15}
# 701
# {'strikePrice': 25000, 'expiryDate': '26-Dec-2024', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY26-12-2024PE25000.00', 'openInterest': 0, 'changeinOpenInterest': 0, 'pchangeinOpenInterest': 0, 'totalTradedVolume': 0, 'impliedVolatility': 0, 'lastPrice': 0, 'change': 0, 'pChange': 0, 'totalBuyQuantity': 50, 'totalSellQuantity': 0, 'bidQty': 50, 'bidprice': 2040.05, 'askQty': 0, 'askPrice': 0, 'underlyingValue': 20133.15}
# 702
# {'strikePrice': 25000, 'expiryDate': '26-Jun-2025', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY26-06-2025PE25000.00', 'openInterest': 0, 'changeinOpenInterest': 0, 'pchangeinOpenInterest': 0, 'totalTradedVolume': 0, 'impliedVolatility': 0, 'lastPrice': 0, 'change': 0, 'pChange': 0, 'totalBuyQuantity': 50, 'totalSellQuantity': 0, 'bidQty': 50, 'bidprice': 1725.05, 'askQty': 0, 'askPrice': 0, 'underlyingValue': 20133.15}
# 703
# {'strikePrice': 25000, 'expiryDate': '24-Dec-2025', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY24-12-2025PE25000.00', 'openInterest': 0, 'changeinOpenInterest': 0, 'pchangeinOpenInterest': 0, 'totalTradedVolume': 0, 'impliedVolatility': 0, 'lastPrice': 0, 'change': 0, 'pChange': 0, 'totalBuyQuantity': 50, 'totalSellQuantity': 0, 'bidQty': 50, 'bidprice': 1500.05, 'askQty': 0, 'askPrice': 0, 'underlyingValue': 20133.15}
# 704
# {'strikePrice': 25000, 'expiryDate': '25-Jun-2026', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY25-06-2026PE25000.00', 'openInterest': 0, 'changeinOpenInterest': 0, 'pchangeinOpenInterest': 0, 'totalTradedVolume': 0, 'impliedVolatility': 0, 'lastPrice': 0, 'change': 0, 'pChange': 0, 'totalBuyQuantity': 50, 'totalSellQuantity': 0, 'bidQty': 50, 'bidprice': 1325.05, 'askQty': 0, 'askPrice': 0, 'underlyingValue': 20133.15}
# 705
# {'strikePrice': 25000, 'expiryDate': '31-Dec-2026', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY31-12-2026PE25000.00', 'openInterest': 0, 'changeinOpenInterest': 0, 'pchangeinOpenInterest': 0, 'totalTradedVolume': 0, 'impliedVolatility': 0, 'lastPrice': 0, 'change': 0, 'pChange': 0, 'totalBuyQuantity': 2150, 'totalSellQuantity': 0, 'bidQty': 50, 'bidprice': 1150.05, 'askQty': 0, 'askPrice': 0, 'underlyingValue': 20133.15}
# 706
# {'strikePrice': 25000, 'expiryDate': '24-Jun-2027', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY24-06-2027PE25000.00', 'openInterest': 0, 'changeinOpenInterest': 0, 'pchangeinOpenInterest': 0, 'totalTradedVolume': 0, 'impliedVolatility': 0, 'lastPrice': 0, 'change': 0, 'pChange': 0, 'totalBuyQuantity': 1850, 'totalSellQuantity': 0, 'bidQty': 50, 'bidprice': 1005.05, 'askQty': 0, 'askPrice': 0, 'underlyingValue': 20133.15}
# 707
# {'strikePrice': 25000, 'expiryDate': '30-Dec-2027', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY30-12-2027PE25000.00', 'openInterest': 0, 'changeinOpenInterest': 0, 'pchangeinOpenInterest': 0, 'totalTradedVolume': 0, 'impliedVolatility': 0, 'lastPrice': 0, 'change': 0, 'pChange': 0, 'totalBuyQuantity': 1850, 'totalSellQuantity': 0, 'bidQty': 50, 'bidprice': 890.05, 'askQty': 0, 'askPrice': 0, 'underlyingValue': 20133.15}
# 708
# {'strikePrice': 25000, 'expiryDate': '29-Jun-2028', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY29-06-2028PE25000.00', 'openInterest': 0, 'changeinOpenInterest': 0, 'pchangeinOpenInterest': 0, 'totalTradedVolume': 0, 'impliedVolatility': 0, 'lastPrice': 0, 'change': 0, 'pChange': 0, 'totalBuyQuantity': 1850, 'totalSellQuantity': 0, 'bidQty': 50, 'bidprice': 800.05, 'askQty': 0, 'askPrice': 0, 'underlyingValue': 20133.15}

# %%
print(PutEuropean[0])
strikePrice=[]
expiryDate=[]
underlying=[]
openInterest=[]
changeinOpenInterest=[]
totalTradedVolume=[]
totalBuyQuantity=[]
totalSellQuantity=[]
print(PutEuropean[0]["underlyingValue"])
for i in PutEuropean:
        if (i['strikePrice']>19000) & (i['strikePrice']<20800) :
                strikePrice.append(i['strikePrice'])
                expiryDate.append(i['expiryDate'])
                underlying.append(i['underlying'])
                openInterest.append(i['openInterest'])
                changeinOpenInterest.append(i['changeinOpenInterest'])
                totalBuyQuantity.append(i['totalBuyQuantity'])
                totalSellQuantity.append(i['totalSellQuantity'])
                totalTradedVolume.append(i['totalTradedVolume'])
dataF={"strikePrice":strikePrice,"ExpiryDate":expiryDate,"UnderLying":underlying,"OpenInterest":openInterest,"Change O/I":changeinOpenInterest,"Total Buyer":totalBuyQuantity,"Total Sell":totalSellQuantity,"Total Volume":totalTradedVolume}
# Out:
# {'strikePrice': 11000, 'expiryDate': '28-Dec-2023', 'underlying': 'NIFTY', 'identifier': 'OPTIDXNIFTY28-12-2023PE11000.00', 'openInterest': 136.5, 'changeinOpenInterest': 1, 'pchangeinOpenInterest': 0.7380073800738007, 'totalTradedVolume': 1, 'impliedVolatility': 76.27, 'lastPrice': 1.7, 'change': 0, 'pChange': 0, 'totalBuyQuantity': 7300, 'totalSellQuantity': 500, 'bidQty': 2050, 'bidprice': 1, 'askQty': 200, 'askPrice': 2.45, 'underlyingValue': 20133.15}
# 20133.15

# %%
df=pd.DataFrame(dataF)
df
# Out:
#      strikePrice   ExpiryDate UnderLying  OpenInterest  Change O/I  \
# 0          19050  30-Nov-2023      NIFTY         37944       30524
# 1          19050  07-Dec-2023      NIFTY          3884         425
# 2          19050  14-Dec-2023      NIFTY           220         -52
# 3          19050  21-Dec-2023      NIFTY            50           1
# 4          19050  28-Dec-2023      NIFTY          1132           7
# ..           ...          ...        ...           ...         ...
# 244        20750  07-Dec-2023      NIFTY             0           0
# 245        20750  14-Dec-2023      NIFTY             0           0
# 246        20750  21-Dec-2023      NIFTY             0           0
# 247        20750  28-Dec-2023      NIFTY             7           3
# 248        20750  25-Jan-2024      NIFTY             0           0
#
#      Total Buyer  Total Sell  Total Volume
# 0         281200      115000        182272
# 1           6150           0         17094
# 2          18850        2850           135
# 3           8700         250            31
# 4          37850        4300          1735
# ..           ...         ...           ...
# 244         4250        4250             0
# 245         4300        4300             0
# 246         1800          50             0
# 247         4850        4850             4
# 248            0         100             0
#
# [249 rows x 8 columns]

# %%
p=[1,7,98,0]
# Out:
# 98

# %%
import requests
import json
import math

# Python program to print
# colored text and background
def strRed(skk):         return "\033[91m {}\033[00m".format(skk)
def strGreen(skk):       return "\033[92m {}\033[00m".format(skk)
def strYellow(skk):      return "\033[93m {}\033[00m".format(skk)
def strLightPurple(skk): return "\033[94m {}\033[00m".format(skk)
def strPurple(skk):      return "\033[95m {}\033[00m".format(skk)
def strCyan(skk):        return "\033[96m {}\033[00m".format(skk)
def strLightGray(skk):   return "\033[97m {}\033[00m".format(skk)
def strBlack(skk):       return "\033[98m {}\033[00m".format(skk)
def strBold(skk):        return "\033[1m {}\033[0m".format(skk)

# Method to get nearest strikes
def round_nearest(x,num=50): return int(math.ceil(float(x)/num)*num)
def nearest_strike_bnf(x): return round_nearest(x,100)
def nearest_strike_nf(x): return round_nearest(x,50)

# Urls for fetching Data
url_oc      = "https://www.nseindia.com/option-chain"
url_bnf     = 'https://www.nseindia.com/api/option-chain-indices?symbol=BANKNIFTY'
url_nf      = 'https://www.nseindia.com/api/option-chain-indices?symbol=NIFTY'
url_indices = "https://www.nseindia.com/api/allIndices"

# Headers
headers = {'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.149 Safari/537.36',
            'accept-language': 'en,gu;q=0.9,hi;q=0.8',
            'accept-encoding': 'gzip, deflate, br'}

sess = requests.Session()
cookies = dict()

# Local methods
def set_cookie():
    request = sess.get(url_oc, headers=headers, timeout=5)
    cookies = dict(request.cookies)

def get_data(url):
    set_cookie()
    response = sess.get(url, headers=headers, timeout=5, cookies=cookies)
    if(response.status_code==401):
        set_cookie()
        response = sess.get(url_nf, headers=headers, timeout=5, cookies=cookies)
    if(response.status_code==200):
        return response.text
    return ""

def set_header():
    global bnf_ul
    global nf_ul
    global bnf_nearest
    global nf_nearest
    response_text = get_data(url_indices)
    data = json.loads(response_text)
    for index in data["data"]:
        if index["index"]=="NIFTY 50":
            nf_ul = index["last"]
            print("nifty")
        if index["index"]=="NIFTY BANK":
            bnf_ul = index["last"]
            print(bnf_ul)
            print("banknifty")
    bnf_nearest=nearest_strike_bnf(bnf_ul)
    nf_nearest=nearest_strike_nf(nf_ul)

# Showing Header in structured format with Last Price and Nearest Strike

def print_header(index="",ul=0,nearest=0):
    print(strPurple( index.ljust(12," ") + " => ")+ strLightPurple(" Last Price: ") + strBold(str(ul)) + strLightPurple(" Nearest Strike: ") + strBold(str(nearest)))

def print_hr():
    print(strYellow("|".rjust(70,"-")))

# Fetching CE and PE data based on Nearest Expiry Date
def print_oi(num,step,nearest,url):
    strike = nearest - (step*num)
    start_strike = nearest - (step*num)
    response_text = get_data(url)
    data = json.loads(response_text)
    currExpiryDate = data["records"]["expiryDates"][0]
    for item in data['records']['data']:
        if item["expiryDate"] == currExpiryDate:
            if item["strikePrice"] == strike and item["strikePrice"] < start_strike+(step*num*2):
                #print(strCyan(str(item["strikePrice"])) + strGreen(" CE ") + "[ " + strBold(str(item["CE"]["openInterest"]).rjust(10," ")) + " ]" + strRed(" PE ")+"[ " + strBold(str(item["PE"]["openInterest"]).rjust(10," ")) + " ]")
                print(data["records"]["expiryDates"][0] + " " + str(item["strikePrice"]) + " CE " + "[ " + strBold(str(item["CE"]["openInterest"]).rjust(10," ")) + " ]" + " PE " + "[ " + strBold(str(item["PE"]["openInterest"]).rjust(10," ")) + " ]")
                strike = strike + step

# Finding highest Open Interest of People's in CE based on CE data         
def highest_oi_CE(num,step,nearest,url):
    strike = nearest - (step*num)
    start_strike = nearest - (step*num)
    response_text = get_data(url)
    data = json.loads(response_text)
    currExpiryDate = data["records"]["expiryDates"][0]
    max_oi = 0
    max_oi_strike = 0
    for item in data['records']['data']:
        if item["expiryDate"] == currExpiryDate:
            if item["strikePrice"] == strike and item["strikePrice"] < start_strike+(step*num*2):
                if item["CE"]["openInterest"] > max_oi:
                    max_oi = item["CE"]["openInterest"]
                    max_oi_strike = item["strikePrice"]
                strike = strike + step
    return max_oi_strike

# Finding highest Open Interest of People's in PE based on PE data 
def highest_oi_PE(num,step,nearest,url):
    strike = nearest - (step*num)
    start_strike = nearest - (step*num)
    response_text = get_data(url)
    data = json.loads(response_text)
    currExpiryDate = data["records"]["expiryDates"][0]
    max_oi = 0
    max_oi_strike = 0
    for item in data['records']['data']:
        if item["expiryDate"] == currExpiryDate:
            if item["strikePrice"] == strike and item["strikePrice"] < start_strike+(step*num*2):
                if item["PE"]["openInterest"] > max_oi:
                    max_oi = item["PE"]["openInterest"]
                    max_oi_strike = item["strikePrice"]
                strike = strike + step
    return max_oi_strike

set_header()
print('\033c')
print_hr()
print_header("Nifty",nf_ul,nf_nearest)
print_hr()
print_oi(10,50,nf_nearest,url_nf)
print_hr()
print_header("Bank Nifty",bnf_ul,bnf_nearest)
print_hr()
print_oi(10,100,bnf_nearest,url_bnf)
print_hr()

# Finding Highest OI in Call Option In Nifty
nf_highestoi_CE = highest_oi_CE(10,50,nf_nearest,url_nf)

# Finding Highet OI in Put Option In Nifty
nf_highestoi_PE = highest_oi_PE(10,50,nf_nearest,url_nf)

# Finding Highest OI in Call Option In Bank Nifty
bnf_highestoi_CE = highest_oi_CE(10,100,bnf_nearest,url_bnf)

# Finding Highest OI in Put Option In Bank Nifty
bnf_highestoi_PE = highest_oi_PE(10,100,bnf_nearest,url_bnf)


print(strCyan(str("Major Support in Nifty:")) + str(nf_highestoi_CE))
print(strCyan(str("Major Resistance in Nifty:")) + str(nf_highestoi_PE))
print(strPurple(str("Major Support in Bank Nifty:")) + str(bnf_highestoi_CE))
print(strPurple(str("Major Resistance in Bank Nifty:")) + str(bnf_highestoi_PE))
# Out:
# nifty
# 44814.2
# banknifty
# c
#  ---------------------------------------------------------------------|
#  Nifty        =>   Last Price:  20267.9  Nearest Strike:  20300
#  ---------------------------------------------------------------------|
# 07-Dec-2023 19800 CE [       18810 ] PE [       77356 ]
# 07-Dec-2023 19850 CE [        3752 ] PE [       27795 ]
# 07-Dec-2023 19900 CE [       27317 ] PE [       87465 ]
# 07-Dec-2023 19950 CE [        3576 ] PE [       20310 ]
# 07-Dec-2023 20000 CE [       40835 ] PE [      133838 ]
# 07-Dec-2023 20050 CE [        6150 ] PE [       28208 ]
# 07-Dec-2023 20100 CE [       20323 ] PE [       93211 ]
# 07-Dec-2023 20150 CE [       16547 ] PE [       36675 ]
# 07-Dec-2023 20200 CE [       51154 ] PE [       93094 ]
# 07-Dec-2023 20250 CE [       29423 ] PE [       30349 ]
# 07-Dec-2023 20300 CE [       85534 ] PE [       51509 ]
# 07-Dec-2023 20350 CE [       31087 ] PE [        6525 ]
# 07-Dec-2023 20400 CE [      104553 ] PE [       15568 ]
# 07-Dec-2023 20450 CE [       46755 ] PE [        2130 ]
# 07-Dec-2023 20500 CE [       85417 ] PE [        8801 ]
# 07-Dec-2023 20550 CE [       21473 ] PE [        1212 ]
# 07-Dec-2023 20600 CE [       83620 ] PE [        2430 ]
# 07-Dec-2023 20650 CE [       33281 ] PE [         309 ]
# 07-Dec-2023 20700 CE [       64558 ] PE [         540 ]
# 07-Dec-2023 20750 CE [       35139 ] PE [          70 ]
#  ---------------------------------------------------------------------|
#  Bank Nifty   =>   Last Price:  44814.2  Nearest Strike:  44900
#  ---------------------------------------------------------------------|
# 06-Dec-2023 43900 CE [        3045 ] PE [       27465 ]
# 06-Dec-2023 44000 CE [       25083 ] PE [       96563 ]
# 06-Dec-2023 44100 CE [        3087 ] PE [       31783 ]
# 06-Dec-2023 44200 CE [        6360 ] PE [       56922 ]
# 06-Dec-2023 44300 CE [       12045 ] PE [       48915 ]
# 06-Dec-2023 44400 CE [       18230 ] PE [       54667 ]
# 06-Dec-2023 44500 CE [       93640 ] PE [      135683 ]
# 06-Dec-2023 44600 CE [       37290 ] PE [       76615 ]
# 06-Dec-2023 44700 CE [       48900 ] PE [       79102 ]
# 06-Dec-2023 44800 CE [       70418 ] PE [       96409 ]
# 06-Dec-2023 44900 CE [       90696 ] PE [       44098 ]
# 06-Dec-2023 45000 CE [      172097 ] PE [       67522 ]
# 06-Dec-2023 45100 CE [       65406 ] PE [       15493 ]
# 06-Dec-2023 45200 CE [       67127 ] PE [       14976 ]
# 06-Dec-2023 45300 CE [       38708 ] PE [        5663 ]
# 06-Dec-2023 45400 CE [       44238 ] PE [        3057 ]
# 06-Dec-2023 45500 CE [       94777 ] PE [       11239 ]
# 06-Dec-2023 45600 CE [       34238 ] PE [        1146 ]
# 06-Dec-2023 45700 CE [       47286 ] PE [        1488 ]
# 06-Dec-2023 45800 CE [       79492 ] PE [         481 ]
#  ---------------------------------------------------------------------|
#  Major Support in Nifty:20400
#  Major Resistance in Nifty:20000
#  Major Support in Bank Nifty:45000
#  Major Resistance in Bank Nifty:44500
